# %%
import os, re
import random, math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 1. 데이터 불러오기

# %%
# 데이터 로드할 때 빠르게 로드할 수 있도록하는 설정 변수
AUTOTUNE = tf.data.experimental.AUTOTUNE
# X-RAY 이미지 사이즈 변수
IMAGE_SIZE = [180, 180]

# 데이터 경로 변수
ROOT_PATH = os.path.join(os.getenv('HOME'), 'aiffel')
TRAIN_PATH = ROOT_PATH + '/chest_xray/data/train/*/*' # *은 모든 디렉토리와 파일을 의미합니다.
VAL_PATH = ROOT_PATH + '/chest_xray/data/val/*/*'
TEST_PATH = ROOT_PATH + '/chest_xray/data/test/*/*'

# 프로젝트를 진행할 때 아래 두 변수를 변경해보세요
BATCH_SIZE = 16
EPOCHS = 25

print(ROOT_PATH)
# Out:
# /aiffel/aiffel

# %%
train_filenames = tf.io.gfile.glob(TRAIN_PATH)
test_filenames = tf.io.gfile.glob(TEST_PATH)
val_filenames = tf.io.gfile.glob(VAL_PATH)

print(len(train_filenames))
print(len(test_filenames))
print(len(val_filenames))
# Out:
# 5216
# 624
# 16

# %% [markdown]
# ### 훈련 데이터에서 검증 데이터 더 가져오기

# %%
# train 데이터와 validation 데이터를 모두 filenames에 담습니다
filenames = tf.io.gfile.glob(TRAIN_PATH)
filenames.extend(tf.io.gfile.glob(VAL_PATH))

# 모아진 filenames를 8:2로 나눕니다
train_size = math.floor(len(filenames)*0.8)
random.seed(8)
random.shuffle(filenames)
train_filenames = filenames[:train_size]
val_filenames = filenames[train_size:]

print(len(train_filenames))
print(len(val_filenames))
# Out:
# 4185
# 1047

# %% [markdown]
# ### 정상 이미지 수와 폐렴 이미지 수 확인

# %%
print(f'Normal image path\n{filenames[0]}')
print(f'Pneumonia image path\n{filenames[2000]}')
# Out:
# Normal image path
# /aiffel/aiffel/chest_xray/data/train/NORMAL/NORMAL2-IM-1317-0001.jpeg
# Pneumonia image path
# /aiffel/aiffel/chest_xray/data/train/PNEUMONIA/person299_bacteria_1418.jpeg

# %%
COUNT_NORMAL = len([filename for filename in train_filenames if "NORMAL" in filename])
print(f"Normal images count in training set: {COUNT_NORMAL}")


COUNT_PNEUMONIA = len([filename for filename in train_filenames if "PNEUMONIA" in filename])
print(f"Pneumonia images count in training set: {COUNT_PNEUMONIA}")
# Out:
# Normal images count in training set: 1072
# Pneumonia images count in training set: 3113

# %%
train_list_ds = tf.data.Dataset.from_tensor_slices(train_filenames)
val_list_ds = tf.data.Dataset.from_tensor_slices(val_filenames)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_list_ds).numpy()
print(f"Training images count: {TRAIN_IMG_COUNT}")

VAL_IMG_COUNT = tf.data.experimental.cardinality(val_list_ds).numpy()
print(f"Validating images count: {VAL_IMG_COUNT}")
# Out:
# Training images count: 4185
# Validating images count: 1047

# %% [markdown]
# ### 라벨 데이터를 만들어주는 함수 생성

# %%
# 파일 경로의 끝에서 두번째 부분을 확인하면 양성과 음성을 구분할 수 있습니다
def get_label(file_path):
    parts = tf.strings.split(file_path, os.path.sep)
    return parts[-2] == "PNEUMONIA"   # 폐렴이면 양성(True), 노말이면 음성(False)

# %%
# 이미지를 알맞은 형식으로 바꿉니다.
def decode_img(img):
    img = tf.image.decode_jpeg(img, channels=3) # 이미지를 uint8 tensor로 수정
    img = tf.image.convert_image_dtype(img, tf.float32) # float32 타입으로 수정
    img = tf.image.resize(img, IMAGE_SIZE) # 이미지 사이즈를 IMAGE_SIZE로 수정
    return img

# 이미지 파일의 경로를 입력하면 이미지와 라벨을 읽어옵니다.
def process_path(file_path):
    label = get_label(file_path) # 라벨 검출
    img = tf.io.read_file(file_path) # 이미지 읽기
    img = decode_img(img) # 이미지를 알맞은 형식으로 수정
    return img, label

# %% [markdown]
# ### train 데이터 셋과 validation 데이터 셋 만들기

# %%
train_ds = train_list_ds.map(process_path, num_parallel_calls=AUTOTUNE) #AUTOTUNE변수를 이용하면 더욱 빠르게 데이터를 처리할 수 있다
val_ds = val_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)

# %%
for image, label in train_ds.take(1):
    print("Image shape: ", image.numpy().shape)
    print("Label: ", label.numpy())
# Out:
# Image shape:  (180, 180, 3)
# Label:  False

# %% [markdown]
# ### 테스트 데이터셋 만들기

# %%
test_list_ds = tf.data.Dataset.list_files(TEST_PATH)
TEST_IMAGE_COUNT = tf.data.experimental.cardinality(test_list_ds).numpy()
test_ds = test_list_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.batch(BATCH_SIZE)

print(TEST_IMAGE_COUNT)
# Out:
# 624

# %%
def prepare_for_training(ds, shuffle_buffer_size=1000):
    ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    ds = ds.repeat()
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

train_ds = prepare_for_training(train_ds)
val_ds = prepare_for_training(val_ds)

# %% [markdown]
# # 2. 데이터 눈으로 확인하기

# %%
# 이미지 배치를 입력하면 여러장의 이미지를 보여줍니다.
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    for n in range(BATCH_SIZE):
        ax = plt.subplot(4,math.ceil(BATCH_SIZE/4),n+1)
        plt.imshow(image_batch[n])
        if label_batch[n]:
            plt.title("PNEUMONIA")
        else:
            plt.title("NORMAL")
        plt.axis("off")


image_batch, label_batch = next(iter(train_ds))
show_batch(image_batch.numpy(), label_batch.numpy())

# %% [markdown]
# # 3. 모델 만들기

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ])
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(IMAGE_SIZE[0], IMAGE_SIZE[1], 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    
    return model

# %% [markdown]
# ### 클래스에 가중치 부여하기

# %%
weight_for_0 = (1 / COUNT_NORMAL)*(TRAIN_IMG_COUNT)/2.0 
weight_for_1 = (1 / COUNT_PNEUMONIA)*(TRAIN_IMG_COUNT)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for NORMAL: {:.2f}'.format(weight_for_0))
print('Weight for PNEUMONIA: {:.2f}'.format(weight_for_1))
# Out:
# Weight for NORMAL: 1.95
# Weight for PNEUMONIA: 0.67

# %% [markdown]
# # 4. 모델 훈련하기

# %%
with tf.device('/GPU:0'):
    model = build_model()

    METRICS = [
        'accuracy',
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall')
    ]
    
    model.compile(
        optimizer='adam',
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
with tf.device('/GPU:0'):
    history = model.fit(
        train_ds,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_ds,
        validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
        class_weight=class_weight,
    )
# Out:
# Epoch 1/25
# 261/261 [==============================] - 61s 187ms/step - loss: 0.4110 - accuracy: 0.8245 - precision: 0.9537 - recall: 0.8030 - val_loss: 0.6886 - val_accuracy: 0.7356 - val_precision: 0.7356 - val_recall: 1.0000
# Epoch 2/25
# 261/261 [==============================] - 49s 188ms/step - loss: 0.2692 - accuracy: 0.9004 - precision: 0.9693 - recall: 0.8944 - val_loss: 1.0031 - val_accuracy: 0.7365 - val_precision: 0.7365 - val_recall: 1.0000
# Epoch 3/25
# 261/261 [==============================] - 49s 188ms/step - loss: 0.2468 - accuracy: 0.9068 - precision: 0.9725 - recall: 0.9002 - val_loss: 0.5539 - val_accuracy: 0.7529 - val_precision: 0.7485 - val_recall: 1.0000
# Epoch 4/25
# 261/261 [==============================] - 49s 190ms/step - loss: 0.1999 - accuracy: 0.9308 - precision: 0.9773 - recall: 0.9286 - val_loss: 0.2187 - val_accuracy: 0.9240 - val_precision: 0.9971 - val_recall: 0.8992
# Epoch 5/25
# 261/261 [==============================] - 51s 196ms/step - loss: 0.1737 - accuracy: 0.9337 - precision: 0.9797 - recall: 0.9302 - val_loss: 0.0882 - val_accuracy: 0.9740 - val_precision: 0.9855 - val_recall: 0.9790
# Epoch 6/25
# 261/261 [==============================] - 54s 209ms/step - loss: 0.1602 - accuracy: 0.9413 - precision: 0.9831 - recall: 0.9372 - val_loss: 0.0726 - val_accuracy: 0.9788 - val_precision: 0.9921 - val_recall: 0.9791
# Epoch 7/25
# 261/261 [==============================] - 47s 181ms/step - loss: 0.1751 - accuracy: 0.9353 - precision: 0.9797 - recall: 0.9325 - val_loss: 0.1462 - val_accuracy: 0.9433 - val_precision: 0.9337 - val_recall: 0.9935
# Epoch 8/25
# 261/261 [==============================] - 47s 179ms/step - loss: 0.1401 - accuracy: 0.9500 - precision: 0.9859 - recall: 0.9461 - val_loss: 0.0914 - val_accuracy: 0.9615 - val_precision: 0.9548 - val_recall: 0.9948
# Epoch 9/25
# 261/261 [==============================] - 46s 176ms/step - loss: 0.1601 - accuracy: 0.9380 - precision: 0.9837 - recall: 0.9320 - val_loss: 0.8247 - val_accuracy: 0.6875 - val_precision: 1.0000 - val_recall: 0.5740
# Epoch 10/25
# 261/261 [==============================] - 47s 180ms/step - loss: 0.1265 - accuracy: 0.9504 - precision: 0.9879 - recall: 0.9450 - val_loss: 0.0565 - val_accuracy: 0.9779 - val_precision: 0.9806 - val_recall: 0.9895
# Epoch 11/25
# 261/261 [==============================] - 46s 177ms/step - loss: 0.1250 - accuracy: 0.9535 - precision: 0.9883 - recall: 0.9488 - val_loss: 0.3792 - val_accuracy: 0.8519 - val_precision: 1.0000 - val_recall: 0.7987
# Epoch 12/25
# 261/261 [==============================] - 46s 176ms/step - loss: 0.1361 - accuracy: 0.9509 - precision: 0.9866 - recall: 0.9469 - val_loss: 0.0612 - val_accuracy: 0.9788 - val_precision: 0.9921 - val_recall: 0.9791
# Epoch 13/25
# 261/261 [==============================] - 48s 182ms/step - loss: 0.1114 - accuracy: 0.9567 - precision: 0.9906 - recall: 0.9509 - val_loss: 0.0673 - val_accuracy: 0.9760 - val_precision: 0.9805 - val_recall: 0.9869
# Epoch 14/25
# 261/261 [==============================] - 46s 178ms/step - loss: 0.1167 - accuracy: 0.9564 - precision: 0.9886 - recall: 0.9522 - val_loss: 0.0861 - val_accuracy: 0.9721 - val_precision: 0.9986 - val_recall: 0.9634
# Epoch 15/25
# 261/261 [==============================] - 46s 178ms/step - loss: 0.1788 - accuracy: 0.9279 - precision: 0.9812 - recall: 0.9210 - val_loss: 0.5463 - val_accuracy: 0.7558 - val_precision: 1.0000 - val_recall: 0.6688
# Epoch 16/25
# 261/261 [==============================] - 47s 182ms/step - loss: 0.1563 - accuracy: 0.9416 - precision: 0.9841 - recall: 0.9364 - val_loss: 0.1962 - val_accuracy: 0.9269 - val_precision: 0.9688 - val_recall: 0.9310
# Epoch 17/25
# 261/261 [==============================] - 47s 181ms/step - loss: 0.1410 - accuracy: 0.9428 - precision: 0.9835 - recall: 0.9388 - val_loss: 0.1952 - val_accuracy: 0.9346 - val_precision: 0.9971 - val_recall: 0.9137
# Epoch 18/25
# 261/261 [==============================] - 47s 180ms/step - loss: 0.1177 - accuracy: 0.9550 - precision: 0.9896 - recall: 0.9495 - val_loss: 0.0922 - val_accuracy: 0.9644 - val_precision: 0.9607 - val_recall: 0.9921
# Epoch 19/25
# 261/261 [==============================] - 47s 181ms/step - loss: 0.1208 - accuracy: 0.9526 - precision: 0.9873 - recall: 0.9486 - val_loss: 0.1142 - val_accuracy: 0.9644 - val_precision: 0.9562 - val_recall: 0.9974
# Epoch 20/25
# 261/261 [==============================] - 47s 179ms/step - loss: 0.1059 - accuracy: 0.9636 - precision: 0.9907 - recall: 0.9601 - val_loss: 0.1031 - val_accuracy: 0.9596 - val_precision: 0.9972 - val_recall: 0.9476
# Epoch 21/25
# 261/261 [==============================] - 47s 182ms/step - loss: 0.0813 - accuracy: 0.9703 - precision: 0.9943 - recall: 0.9654 - val_loss: 0.1264 - val_accuracy: 0.9500 - val_precision: 0.9945 - val_recall: 0.9374
# Epoch 22/25
# 261/261 [==============================] - 46s 177ms/step - loss: 0.0827 - accuracy: 0.9705 - precision: 0.9934 - recall: 0.9669 - val_loss: 0.0897 - val_accuracy: 0.9673 - val_precision: 0.9716 - val_recall: 0.9843
# Epoch 23/25
# 261/261 [==============================] - 46s 178ms/step - loss: 0.0855 - accuracy: 0.9693 - precision: 0.9921 - recall: 0.9665 - val_loss: 0.0778 - val_accuracy: 0.9712 - val_precision: 0.9986 - val_recall: 0.9620
# Epoch 24/25
# 261/261 [==============================] - 47s 180ms/step - loss: 0.0967 - accuracy: 0.9674 - precision: 0.9924 - recall: 0.9636 - val_loss: 0.0634 - val_accuracy: 0.9760 - val_precision: 0.9947 - val_recall: 0.9725
# Epoch 25/25
# 261/261 [==============================] - 47s 182ms/step - loss: 0.0864 - accuracy: 0.9672 - precision: 0.9934 - recall: 0.9625 - val_loss: 0.1649 - val_accuracy: 0.9394 - val_precision: 0.9944 - val_recall: 0.9229

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['precision', 'recall', 'accuracy', 'loss']):
    ax[i].plot(history.history[met])
    ax[i].plot(history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# # 5. 모델 평가하기

# %%
loss, accuracy, precision, recall = model.evaluate(test_ds)
print(f'Loss: {loss},\nAccuracy: {accuracy},\nPrecision: {precision},\nRecall: {recall}')
# Out:
# 39/39 [==============================] - 5s 115ms/step - loss: 1.3789 - accuracy: 0.8478 - precision: 0.8300 - recall: 0.9513
# Loss: 1.3789337873458862,
# Accuracy: 0.8477563858032227,
# Precision: 0.8299776315689087,
# Recall: 0.9512820243835449
