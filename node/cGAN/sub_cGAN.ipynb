# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers, Input, Model
from tensorflow.keras import optimizers, losses
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation
from tensorflow import data
import cv2
import os

# %%
'''
from zipfile import ZipFile

zippath = os.getenv('HOME')+'/aiffel/conditional_generation'
with ZipFile('cityscapes.zip', 'r') as zip:
    zip.extractall(zippath + '/cityscapes')
    print('File is unzipped in cityscapes folder')
'''
# Out:
# "\nfrom zipfile import ZipFile\n\nzippath = os.getenv('HOME')+'/aiffel/conditional_generation'\nwith ZipFile('cityscapes.zip', 'r') as zip:\n    zip.extractall(zippath + '/cityscapes')\n    print('File is unzipped in cityscapes folder')\n"

# %%
import numpy
import tensorflow

print(numpy.__version__)
print(tensorflow.__version__)
# Out:
# 1.21.4
# 2.6.0

# %%
data_path = os.getenv('HOME')+'/aiffel/conditional_generation/cityscapes/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1000

# %%
plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

# %%
def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, w:, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, :w, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))
plt.show()

# %%
@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]

# %%
plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))
plt.show();

# %%
class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block (EncodeBlock)      (None, 128, 128, 64) 3072        input_1[0][0]
# __________________________________________________________________________________________________
# encode_block_1 (EncodeBlock)    (None, 64, 64, 128)  131584      encode_block[0][0]
# __________________________________________________________________________________________________
# encode_block_2 (EncodeBlock)    (None, 32, 32, 256)  525312      encode_block_1[0][0]
# __________________________________________________________________________________________________
# encode_block_3 (EncodeBlock)    (None, 16, 16, 512)  2099200     encode_block_2[0][0]
# __________________________________________________________________________________________________
# encode_block_4 (EncodeBlock)    (None, 8, 8, 512)    4196352     encode_block_3[0][0]
# __________________________________________________________________________________________________
# encode_block_5 (EncodeBlock)    (None, 4, 4, 512)    4196352     encode_block_4[0][0]
# __________________________________________________________________________________________________
# encode_block_6 (EncodeBlock)    (None, 2, 2, 512)    4196352     encode_block_5[0][0]
# __________________________________________________________________________________________________
# encode_block_7 (EncodeBlock)    (None, 1, 1, 512)    4196352     encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block (DecodeBlock)      (None, 2, 2, 512)    4196352     encode_block_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 2, 2, 1024)   0           decode_block[0][0]
#                                                                  encode_block_6[0][0]
# __________________________________________________________________________________________________
# decode_block_1 (DecodeBlock)    (None, 4, 4, 512)    8390656     concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 4, 4, 1024)   0           decode_block_1[0][0]
#                                                                  encode_block_5[0][0]
# __________________________________________________________________________________________________
# decode_block_2 (DecodeBlock)    (None, 8, 8, 512)    8390656     concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 8, 8, 1024)   0           decode_block_2[0][0]
#                                                                  encode_block_4[0][0]
# __________________________________________________________________________________________________
# decode_block_3 (DecodeBlock)    (None, 16, 16, 512)  8390656     concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 16, 16, 1024) 0           decode_block_3[0][0]
#                                                                  encode_block_3[0][0]
# __________________________________________________________________________________________________
# decode_block_4 (DecodeBlock)    (None, 32, 32, 256)  4195328     concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 512)  0           decode_block_4[0][0]
#                                                                  encode_block_2[0][0]
# __________________________________________________________________________________________________
# decode_block_5 (DecodeBlock)    (None, 64, 64, 128)  1049088     concatenate_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64, 64, 256)  0           decode_block_5[0][0]
#                                                                  encode_block_1[0][0]
# __________________________________________________________________________________________________
# decode_block_6 (DecodeBlock)    (None, 128, 128, 64) 262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 128, 128, 128 0           decode_block_6[0][0]
#                                                                  encode_block[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 256, 256, 3)  6144        concatenate_6[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %% [markdown]
# ### Discriminator 구현하기

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()

# %%
Discriminator().get_summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 6)  0           input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# disc_block (DiscBlock)          (None, 128, 128, 64) 6144        concatenate_7[0][0]
# __________________________________________________________________________________________________
# disc_block_1 (DiscBlock)        (None, 64, 64, 128)  131584      disc_block[0][0]
# __________________________________________________________________________________________________
# disc_block_2 (DiscBlock)        (None, 32, 32, 256)  525312      disc_block_1[0][0]
# __________________________________________________________________________________________________
# disc_block_3 (DiscBlock)        (None, 31, 31, 512)  2099200     disc_block_2[0][0]
# __________________________________________________________________________________________________
# disc_block_4 (DiscBlock)        (None, 30, 30, 1)    8192        disc_block_3[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 30, 30, 1)    0           disc_block_4[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

# %%
gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

# %%
EPOCHS = 30

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:0.8634
# L1_loss:0.3010
# Discriminator_loss:1.3786
#
# EPOCH[1] - STEP[20]
# Generator_loss:0.8616
# L1_loss:0.2604
# Discriminator_loss:1.3247
#
# EPOCH[1] - STEP[30]
# Generator_loss:0.8956
# L1_loss:0.2414
# Discriminator_loss:1.4031
#
# EPOCH[1] - STEP[40]
# Generator_loss:0.6852
# L1_loss:0.2027
# Discriminator_loss:1.3761
#
# EPOCH[1] - STEP[50]
# Generator_loss:0.9477
# L1_loss:0.2368
# Discriminator_loss:1.1577
#
# EPOCH[1] - STEP[60]
# Generator_loss:0.7666
# L1_loss:0.1682
# Discriminator_loss:1.4180
#
# EPOCH[1] - STEP[70]
# Generator_loss:1.1259
# L1_loss:0.2153
# Discriminator_loss:1.1605
#
# EPOCH[1] - STEP[80]
# Generator_loss:0.9362
# L1_loss:0.1861
# Discriminator_loss:0.9778
#
# EPOCH[1] - STEP[90]
# Generator_loss:0.7875
# L1_loss:0.1929
# Discriminator_loss:1.5268
#
# EPOCH[1] - STEP[100]
# Generator_loss:1.0966
# L1_loss:0.1698
# Discriminator_loss:1.0746
#
# EPOCH[1] - STEP[110]
# Generator_loss:1.0537
# L1_loss:0.2114
# Discriminator_loss:1.0936
#
# EPOCH[1] - STEP[120]
# Generator_loss:0.9578
# L1_loss:0.1689
# Discriminator_loss:1.0989
#
# EPOCH[1] - STEP[130]
# Generator_loss:0.8510
# L1_loss:0.2269
# Discriminator_loss:1.0579
#
# EPOCH[1] - STEP[140]
# Generator_loss:1.3670
# L1_loss:0.2085
# Discriminator_loss:0.8152
#
# EPOCH[1] - STEP[150]
# Generator_loss:1.0553
# L1_loss:0.2072
# Discriminator_loss:0.8878
#
# EPOCH[1] - STEP[160]
# Generator_loss:1.4075
# L1_loss:0.2029
# Discriminator_loss:0.8634
#
# EPOCH[1] - STEP[170]
# Generator_loss:0.8850
# L1_loss:0.1730
# Discriminator_loss:0.9392
#
# EPOCH[1] - STEP[180]
# Generator_loss:1.7797
# L1_loss:0.1529
# Discriminator_loss:1.0161
#
# EPOCH[1] - STEP[190]
# Generator_loss:1.7321
# L1_loss:0.1544
# Discriminator_loss:1.3257
#
# EPOCH[1] - STEP[200]
# Generator_loss:0.8449
# L1_loss:0.1958
# Discriminator_loss:0.8076
#
# EPOCH[1] - STEP[210]
# Generator_loss:1.6281
# L1_loss:0.1702
# Discriminator_loss:0.7272
#
# EPOCH[1] - STEP[220]
# Generator_loss:2.2452
# L1_loss:0.2041
# Discriminator_loss:0.3931
#
# EPOCH[1] - STEP[230]
# Generator_loss:0.9513
# L1_loss:0.1624
# Discriminator_loss:0.7223
#
# EPOCH[1] - STEP[240]
# Generator_loss:1.3653
# L1_loss:0.2284
# Discriminator_loss:0.6284
#
# EPOCH[1] - STEP[250]
# Generator_loss:1.2701
# L1_loss:0.2488
# Discriminator_loss:0.7725
#
# EPOCH[2] - STEP[10]
# Generator_loss:1.6764
# L1_loss:0.2025
# Discriminator_loss:0.5026
#
# EPOCH[2] - STEP[20]
# Generator_loss:1.4113
# L1_loss:0.1608
# Discriminator_loss:0.9464
#
# EPOCH[2] - STEP[30]
# Generator_loss:1.5629
# L1_loss:0.2205
# Discriminator_loss:0.4756
#
# EPOCH[2] - STEP[40]
# Generator_loss:0.7929
# L1_loss:0.1888
# Discriminator_loss:1.3339
#
# EPOCH[2] - STEP[50]
# Generator_loss:2.4007
# L1_loss:0.1842
# Discriminator_loss:0.3805
#
# EPOCH[2] - STEP[60]
# Generator_loss:2.3910
# L1_loss:0.1798
# Discriminator_loss:0.8485
#
# EPOCH[2] - STEP[70]
# Generator_loss:2.0534
# L1_loss:0.1852
# Discriminator_loss:0.4698
#
# EPOCH[2] - STEP[80]
# Generator_loss:1.8018
# L1_loss:0.1699
# Discriminator_loss:1.2307
#
# EPOCH[2] - STEP[90]
# Generator_loss:2.1337
# L1_loss:0.1801
# Discriminator_loss:0.6769
#
# EPOCH[2] - STEP[100]
# Generator_loss:1.7296
# L1_loss:0.1875
# Discriminator_loss:0.4874
#
# EPOCH[2] - STEP[110]
# Generator_loss:1.1606
# L1_loss:0.1698
# Discriminator_loss:0.7291
#
# EPOCH[2] - STEP[120]
# Generator_loss:2.0821
# L1_loss:0.1938
# Discriminator_loss:0.2812
#
# EPOCH[2] - STEP[130]
# Generator_loss:1.3071
# L1_loss:0.1667
# Discriminator_loss:0.6888
#
# EPOCH[2] - STEP[140]
# Generator_loss:1.5151
# L1_loss:0.1762
# Discriminator_loss:0.7069
#
# EPOCH[2] - STEP[150]
# Generator_loss:2.0401
# L1_loss:0.1773
# Discriminator_loss:0.4748
#
# EPOCH[2] - STEP[160]
# Generator_loss:1.7682
# L1_loss:0.1800
# Discriminator_loss:0.9656
#
# EPOCH[2] - STEP[170]
# Generator_loss:1.2785
# L1_loss:0.1746
# Discriminator_loss:0.7239
#
# EPOCH[2] - STEP[180]
# Generator_loss:0.7133
# L1_loss:0.1495
# Discriminator_loss:1.0136
#
# EPOCH[2] - STEP[190]
# Generator_loss:1.8090
# L1_loss:0.1961
# Discriminator_loss:0.5761
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.3854
# L1_loss:0.2014
# Discriminator_loss:0.7448
#
# EPOCH[2] - STEP[210]
# Generator_loss:1.1217
# L1_loss:0.1873
# Discriminator_loss:0.8248
#
# EPOCH[2] - STEP[220]
# Generator_loss:1.1299
# L1_loss:0.2035
# Discriminator_loss:0.8142
#
# EPOCH[2] - STEP[230]
# Generator_loss:1.1461
# L1_loss:0.2095
# Discriminator_loss:0.6916
#
# EPOCH[2] - STEP[240]
# Generator_loss:0.5871
# L1_loss:0.1740
# Discriminator_loss:1.0698
#
# EPOCH[2] - STEP[250]
# Generator_loss:1.4663
# L1_loss:0.1834
# Discriminator_loss:0.4448
#
# EPOCH[3] - STEP[10]
# Generator_loss:0.9788
# L1_loss:0.1741
# Discriminator_loss:1.2311
#
# EPOCH[3] - STEP[20]
# Generator_loss:2.3426
# L1_loss:0.2173
# Discriminator_loss:0.2168
#
# EPOCH[3] - STEP[30]
# Generator_loss:0.9063
# L1_loss:0.1696
# Discriminator_loss:1.0249
#
# EPOCH[3] - STEP[40]
# Generator_loss:1.2415
# L1_loss:0.1985
# Discriminator_loss:0.7422
#
# EPOCH[3] - STEP[50]
# Generator_loss:1.9789
# L1_loss:0.1595
# Discriminator_loss:0.3636
#
# EPOCH[3] - STEP[60]
# Generator_loss:2.3835
# L1_loss:0.2068
# Discriminator_loss:0.2878
#
# EPOCH[3] - STEP[70]
# Generator_loss:2.4133
# L1_loss:0.1768
# Discriminator_loss:0.2515
#
# EPOCH[3] - STEP[80]
# Generator_loss:1.3251
# L1_loss:0.1607
# Discriminator_loss:1.5927
#
# EPOCH[3] - STEP[90]
# Generator_loss:1.5278
# L1_loss:0.2016
# Discriminator_loss:0.8769
#
# EPOCH[3] - STEP[100]
# Generator_loss:2.2280
# L1_loss:0.1733
# Discriminator_loss:0.5093
#
# EPOCH[3] - STEP[110]
# Generator_loss:2.2634
# L1_loss:0.1495
# Discriminator_loss:0.9830
#
# EPOCH[3] - STEP[120]
# Generator_loss:2.7711
# L1_loss:0.1968
# Discriminator_loss:1.1490
#
# EPOCH[3] - STEP[130]
# Generator_loss:2.6952
# L1_loss:0.1889
# Discriminator_loss:0.8260
#
# EPOCH[3] - STEP[140]
# Generator_loss:0.9667
# L1_loss:0.1986
# Discriminator_loss:1.4352
#
# EPOCH[3] - STEP[150]
# Generator_loss:2.3152
# L1_loss:0.2013
# Discriminator_loss:0.3690
#
# EPOCH[3] - STEP[160]
# Generator_loss:0.8108
# L1_loss:0.1614
# Discriminator_loss:0.8332
#
# EPOCH[3] - STEP[170]
# Generator_loss:2.1168
# L1_loss:0.2003
# Discriminator_loss:0.6239
#
# EPOCH[3] - STEP[180]
# Generator_loss:2.2010
# L1_loss:0.1842
# Discriminator_loss:0.3549
#
# EPOCH[3] - STEP[190]
# Generator_loss:2.8211
# L1_loss:0.1392
# Discriminator_loss:1.4294
#
# EPOCH[3] - STEP[200]
# Generator_loss:1.9379
# L1_loss:0.1883
# Discriminator_loss:0.6165
#
# EPOCH[3] - STEP[210]
# Generator_loss:1.1080
# L1_loss:0.1810
# Discriminator_loss:0.6976
#
# EPOCH[3] - STEP[220]
# Generator_loss:1.9112
# L1_loss:0.1976
# Discriminator_loss:0.3904
#
# EPOCH[3] - STEP[230]
# Generator_loss:2.3539
# L1_loss:0.1743
# Discriminator_loss:0.7468
#
# EPOCH[3] - STEP[240]
# Generator_loss:2.5118
# L1_loss:0.1754
# Discriminator_loss:0.9040
#
# EPOCH[3] - STEP[250]
# Generator_loss:1.8868
# L1_loss:0.2009
# Discriminator_loss:0.4465
#
# EPOCH[4] - STEP[10]
# Generator_loss:1.3331
# L1_loss:0.1815
# Discriminator_loss:1.5724
#
# EPOCH[4] - STEP[20]
# Generator_loss:2.0361
# L1_loss:0.1758
# Discriminator_loss:0.5174
#
# EPOCH[4] - STEP[30]
# Generator_loss:2.0754
# L1_loss:0.1763
# Discriminator_loss:0.3071
#
# EPOCH[4] - STEP[40]
# Generator_loss:3.2768
# L1_loss:0.1875
# Discriminator_loss:1.2730
#
# EPOCH[4] - STEP[50]
# Generator_loss:1.4133
# L1_loss:0.2034
# Discriminator_loss:0.5311
#
# EPOCH[4] - STEP[60]
# Generator_loss:1.1253
# L1_loss:0.1784
# Discriminator_loss:1.4445
#
# EPOCH[4] - STEP[70]
# Generator_loss:1.5012
# L1_loss:0.1859
# Discriminator_loss:1.5627
#
# EPOCH[4] - STEP[80]
# Generator_loss:2.0757
# L1_loss:0.1469
# Discriminator_loss:1.2212
#
# EPOCH[4] - STEP[90]
# Generator_loss:1.3114
# L1_loss:0.1951
# Discriminator_loss:0.5180
#
# EPOCH[4] - STEP[100]
# Generator_loss:1.1574
# L1_loss:0.2042
# Discriminator_loss:0.6630
#
# EPOCH[4] - STEP[110]
# Generator_loss:2.3532
# L1_loss:0.1807
# Discriminator_loss:0.3361
#
# EPOCH[4] - STEP[120]
# Generator_loss:2.0867
# L1_loss:0.1902
# Discriminator_loss:0.8614
#
# EPOCH[4] - STEP[130]
# Generator_loss:2.2750
# L1_loss:0.1790
# Discriminator_loss:0.6610
#
# EPOCH[4] - STEP[140]
# Generator_loss:0.9135
# L1_loss:0.1918
# Discriminator_loss:0.6929
#
# EPOCH[4] - STEP[150]
# Generator_loss:0.5959
# L1_loss:0.1772
# Discriminator_loss:1.2242
#
# EPOCH[4] - STEP[160]
# Generator_loss:0.9122
# L1_loss:0.1636
# Discriminator_loss:2.3851
#
# EPOCH[4] - STEP[170]
# Generator_loss:1.7413
# L1_loss:0.1866
# Discriminator_loss:0.3901
#
# EPOCH[4] - STEP[180]
# Generator_loss:1.9317
# L1_loss:0.1684
# Discriminator_loss:0.7408
#
# EPOCH[4] - STEP[190]
# Generator_loss:2.4893
# L1_loss:0.2261
# Discriminator_loss:0.1852
#
# EPOCH[4] - STEP[200]
# Generator_loss:0.7514
# L1_loss:0.1794
# Discriminator_loss:0.8225
#
# EPOCH[4] - STEP[210]
# Generator_loss:2.3435
# L1_loss:0.1832
# Discriminator_loss:0.4930
#
# EPOCH[4] - STEP[220]
# Generator_loss:2.0885
# L1_loss:0.1739
# Discriminator_loss:0.3727
#
# EPOCH[4] - STEP[230]
# Generator_loss:1.6022
# L1_loss:0.1574
# Discriminator_loss:1.5268
#
# EPOCH[4] - STEP[240]
# Generator_loss:0.8360
# L1_loss:0.1976
# Discriminator_loss:0.7485
#
# EPOCH[4] - STEP[250]
# Generator_loss:0.7436
# L1_loss:0.2033
# Discriminator_loss:0.9968
#
# EPOCH[5] - STEP[10]
# Generator_loss:2.0295
# L1_loss:0.1661
# Discriminator_loss:0.7310
#
# EPOCH[5] - STEP[20]
# Generator_loss:1.3962
# L1_loss:0.1679
# Discriminator_loss:0.3886
#
# EPOCH[5] - STEP[30]
# Generator_loss:1.9364
# L1_loss:0.1836
# Discriminator_loss:0.5794
#
# EPOCH[5] - STEP[40]
# Generator_loss:1.7584
# L1_loss:0.1978
# Discriminator_loss:0.3069
#
# EPOCH[5] - STEP[50]
# Generator_loss:2.1144
# L1_loss:0.1789
# Discriminator_loss:1.9762
#
# EPOCH[5] - STEP[60]
# Generator_loss:0.9998
# L1_loss:0.1963
# Discriminator_loss:0.8441
#
# EPOCH[5] - STEP[70]
# Generator_loss:0.2457
# L1_loss:0.1866
# Discriminator_loss:1.8075
#
# EPOCH[5] - STEP[80]
# Generator_loss:2.6853
# L1_loss:0.1697
# Discriminator_loss:0.5383
#
# EPOCH[5] - STEP[90]
# Generator_loss:1.0820
# L1_loss:0.1803
# Discriminator_loss:1.1416
#
# EPOCH[5] - STEP[100]
# Generator_loss:1.6531
# L1_loss:0.1575
# Discriminator_loss:0.6851
#
# EPOCH[5] - STEP[110]
# Generator_loss:1.6865
# L1_loss:0.1589
# Discriminator_loss:0.5975
#
# EPOCH[5] - STEP[120]
# Generator_loss:1.6198
# L1_loss:0.1652
# Discriminator_loss:1.3777
#
# EPOCH[5] - STEP[130]
# Generator_loss:2.3124
# L1_loss:0.1708
# Discriminator_loss:1.1355
#
# EPOCH[5] - STEP[140]
# Generator_loss:0.9824
# L1_loss:0.1615
# Discriminator_loss:1.1278
#
# EPOCH[5] - STEP[150]
# Generator_loss:2.0837
# L1_loss:0.1731
# Discriminator_loss:0.8593
#
# EPOCH[5] - STEP[160]
# Generator_loss:1.2660
# L1_loss:0.2012
# Discriminator_loss:0.5817
#
# EPOCH[5] - STEP[170]
# Generator_loss:1.6739
# L1_loss:0.1682
# Discriminator_loss:0.4375
#
# EPOCH[5] - STEP[180]
# Generator_loss:1.0121
# L1_loss:0.1960
# Discriminator_loss:1.0672
#
# EPOCH[5] - STEP[190]
# Generator_loss:1.7994
# L1_loss:0.2389
# Discriminator_loss:0.2464
#
# EPOCH[5] - STEP[200]
# Generator_loss:0.7371
# L1_loss:0.1929
# Discriminator_loss:1.0874
#
# EPOCH[5] - STEP[210]
# Generator_loss:1.4540
# L1_loss:0.1759
# Discriminator_loss:0.5987
#
# EPOCH[5] - STEP[220]
# Generator_loss:0.7259
# L1_loss:0.2044
# Discriminator_loss:0.8534
#
# EPOCH[5] - STEP[230]
# Generator_loss:0.9614
# L1_loss:0.2350
# Discriminator_loss:0.7196
#
# EPOCH[5] - STEP[240]
# Generator_loss:1.7688
# L1_loss:0.1630
# Discriminator_loss:0.7312
#
# EPOCH[5] - STEP[250]
# Generator_loss:1.8421
# L1_loss:0.1853
# Discriminator_loss:0.3156
#
# EPOCH[6] - STEP[10]
# Generator_loss:3.2676
# L1_loss:0.1829
# Discriminator_loss:0.3252
#
# EPOCH[6] - STEP[20]
# Generator_loss:0.8835
# L1_loss:0.1623
# Discriminator_loss:1.1138
#
# EPOCH[6] - STEP[30]
# Generator_loss:2.0354
# L1_loss:0.1873
# Discriminator_loss:0.5467
#
# EPOCH[6] - STEP[40]
# Generator_loss:0.8245
# L1_loss:0.2032
# Discriminator_loss:1.0636
#
# EPOCH[6] - STEP[50]
# Generator_loss:2.6906
# L1_loss:0.1783
# Discriminator_loss:0.4575
#
# EPOCH[6] - STEP[60]
# Generator_loss:1.9053
# L1_loss:0.1981
# Discriminator_loss:0.7046
#
# EPOCH[6] - STEP[70]
# Generator_loss:1.5461
# L1_loss:0.1972
# Discriminator_loss:0.6455
#
# EPOCH[6] - STEP[80]
# Generator_loss:2.3422
# L1_loss:0.1518
# Discriminator_loss:1.3198
#
# EPOCH[6] - STEP[90]
# Generator_loss:1.2761
# L1_loss:0.1724
# Discriminator_loss:1.6770
#
# EPOCH[6] - STEP[100]
# Generator_loss:0.5020
# L1_loss:0.2173
# Discriminator_loss:1.2150
#
# EPOCH[6] - STEP[110]
# Generator_loss:1.0916
# L1_loss:0.2301
# Discriminator_loss:0.5441
#
# EPOCH[6] - STEP[120]
# Generator_loss:0.7315
# L1_loss:0.2099
# Discriminator_loss:1.2026
#
# EPOCH[6] - STEP[130]
# Generator_loss:1.6601
# L1_loss:0.1930
# Discriminator_loss:0.4787
#
# EPOCH[6] - STEP[140]
# Generator_loss:0.8615
# L1_loss:0.2140
# Discriminator_loss:0.8766
#
# EPOCH[6] - STEP[150]
# Generator_loss:0.4806
# L1_loss:0.2179
# Discriminator_loss:1.1305
#
# EPOCH[6] - STEP[160]
# Generator_loss:0.8420
# L1_loss:0.1482
# Discriminator_loss:1.0518
#
# EPOCH[6] - STEP[170]
# Generator_loss:1.1660
# L1_loss:0.2397
# Discriminator_loss:0.5708
#
# EPOCH[6] - STEP[180]
# Generator_loss:1.1592
# L1_loss:0.1822
# Discriminator_loss:2.2946
#
# EPOCH[6] - STEP[190]
# Generator_loss:1.3763
# L1_loss:0.1726
# Discriminator_loss:0.8075
#
# EPOCH[6] - STEP[200]
# Generator_loss:0.9816
# L1_loss:0.1891
# Discriminator_loss:0.5781
#
# EPOCH[6] - STEP[210]
# Generator_loss:1.8595
# L1_loss:0.1572
# Discriminator_loss:2.0444
#
# EPOCH[6] - STEP[220]
# Generator_loss:2.5978
# L1_loss:0.2125
# Discriminator_loss:0.1578
#
# EPOCH[6] - STEP[230]
# Generator_loss:1.9069
# L1_loss:0.1940
# Discriminator_loss:0.6519
#
# EPOCH[6] - STEP[240]
# Generator_loss:0.8067
# L1_loss:0.2066
# Discriminator_loss:1.1392
#
# EPOCH[6] - STEP[250]
# Generator_loss:1.7313
# L1_loss:0.1756
# Discriminator_loss:1.0185
#
# EPOCH[7] - STEP[10]
# Generator_loss:1.5886
# L1_loss:0.1700
# Discriminator_loss:0.8053
#
# EPOCH[7] - STEP[20]
# Generator_loss:0.4407
# L1_loss:0.1690
# Discriminator_loss:1.3043
#
# EPOCH[7] - STEP[30]
# Generator_loss:3.3064
# L1_loss:0.1990
# Discriminator_loss:1.2541
#
# EPOCH[7] - STEP[40]
# Generator_loss:2.4037
# L1_loss:0.2107
# Discriminator_loss:0.2023
#
# EPOCH[7] - STEP[50]
# Generator_loss:2.1229
# L1_loss:0.1804
# Discriminator_loss:0.4470
#
# EPOCH[7] - STEP[60]
# Generator_loss:0.3433
# L1_loss:0.2129
# Discriminator_loss:1.7957
#
# EPOCH[7] - STEP[70]
# Generator_loss:0.7319
# L1_loss:0.1875
# Discriminator_loss:0.9360
#
# EPOCH[7] - STEP[80]
# Generator_loss:0.9526
# L1_loss:0.1967
# Discriminator_loss:0.6169
#
# EPOCH[7] - STEP[90]
# Generator_loss:0.6983
# L1_loss:0.2199
# Discriminator_loss:0.9339
#
# EPOCH[7] - STEP[100]
# Generator_loss:1.1820
# L1_loss:0.1895
# Discriminator_loss:0.5738
#
# EPOCH[7] - STEP[110]
# Generator_loss:2.2210
# L1_loss:0.1967
# Discriminator_loss:3.2908
#
# EPOCH[7] - STEP[120]
# Generator_loss:2.1228
# L1_loss:0.1492
# Discriminator_loss:1.3550
#
# EPOCH[7] - STEP[130]
# Generator_loss:0.3941
# L1_loss:0.1596
# Discriminator_loss:1.4448
#
# EPOCH[7] - STEP[140]
# Generator_loss:2.1632
# L1_loss:0.1528
# Discriminator_loss:0.9327
#
# EPOCH[7] - STEP[150]
# Generator_loss:1.8904
# L1_loss:0.1954
# Discriminator_loss:0.2495
#
# EPOCH[7] - STEP[160]
# Generator_loss:2.1747
# L1_loss:0.2305
# Discriminator_loss:0.2498
#
# EPOCH[7] - STEP[170]
# Generator_loss:0.6856
# L1_loss:0.1931
# Discriminator_loss:1.3803
#
# EPOCH[7] - STEP[180]
# Generator_loss:2.3196
# L1_loss:0.1824
# Discriminator_loss:0.4882
#
# EPOCH[7] - STEP[190]
# Generator_loss:1.4085
# L1_loss:0.1958
# Discriminator_loss:0.5052
#
# EPOCH[7] - STEP[200]
# Generator_loss:1.9896
# L1_loss:0.1915
# Discriminator_loss:0.3003
#
# EPOCH[7] - STEP[210]
# Generator_loss:2.4643
# L1_loss:0.1898
# Discriminator_loss:0.5026
#
# EPOCH[7] - STEP[220]
# Generator_loss:1.1509
# L1_loss:0.1746
# Discriminator_loss:1.4477
#
# EPOCH[7] - STEP[230]
# Generator_loss:0.8953
# L1_loss:0.1729
# Discriminator_loss:1.4507
#
# EPOCH[7] - STEP[240]
# Generator_loss:1.7181
# L1_loss:0.1796
# Discriminator_loss:0.7651
#
# EPOCH[7] - STEP[250]
# Generator_loss:0.3397
# L1_loss:0.1962
# Discriminator_loss:1.3922
#
# EPOCH[8] - STEP[10]
# Generator_loss:2.1746
# L1_loss:0.1635
# Discriminator_loss:0.3876
#
# EPOCH[8] - STEP[20]
# Generator_loss:2.0761
# L1_loss:0.2001
# Discriminator_loss:1.4395
#
# EPOCH[8] - STEP[30]
# Generator_loss:1.2854
# L1_loss:0.1868
# Discriminator_loss:0.9649
#
# EPOCH[8] - STEP[40]
# Generator_loss:0.3507
# L1_loss:0.1968
# Discriminator_loss:1.4291
#
# EPOCH[8] - STEP[50]
# Generator_loss:1.0880
# L1_loss:0.1968
# Discriminator_loss:0.5530
#
# EPOCH[8] - STEP[60]
# Generator_loss:1.6253
# L1_loss:0.1501
# Discriminator_loss:1.2581
#
# EPOCH[8] - STEP[70]
# Generator_loss:1.2683
# L1_loss:0.1501
# Discriminator_loss:0.8858
#
# EPOCH[8] - STEP[80]
# Generator_loss:1.2088
# L1_loss:0.1889
# Discriminator_loss:0.6014
#
# EPOCH[8] - STEP[90]
# Generator_loss:2.1964
# L1_loss:0.2079
# Discriminator_loss:0.5035
#
# EPOCH[8] - STEP[100]
# Generator_loss:2.1543
# L1_loss:0.1698
# Discriminator_loss:0.5222
#
# EPOCH[8] - STEP[110]
# Generator_loss:0.8344
# L1_loss:0.1584
# Discriminator_loss:1.7742
#
# EPOCH[8] - STEP[120]
# Generator_loss:2.3236
# L1_loss:0.1782
# Discriminator_loss:0.5666
#
# EPOCH[8] - STEP[130]
# Generator_loss:1.2679
# L1_loss:0.2229
# Discriminator_loss:0.4149
#
# EPOCH[8] - STEP[140]
# Generator_loss:1.2016
# L1_loss:0.1827
# Discriminator_loss:0.6229
#
# EPOCH[8] - STEP[150]
# Generator_loss:0.6779
# L1_loss:0.1700
# Discriminator_loss:1.2211
#
# EPOCH[8] - STEP[160]
# Generator_loss:0.5316
# L1_loss:0.1656
# Discriminator_loss:1.7182
#
# EPOCH[8] - STEP[170]
# Generator_loss:2.2176
# L1_loss:0.1866
# Discriminator_loss:0.2340
#
# EPOCH[8] - STEP[180]
# Generator_loss:0.9841
# L1_loss:0.2184
# Discriminator_loss:0.9300
#
# EPOCH[8] - STEP[190]
# Generator_loss:0.9820
# L1_loss:0.1996
# Discriminator_loss:0.7348
#
# EPOCH[8] - STEP[200]
# Generator_loss:1.8049
# L1_loss:0.1455
# Discriminator_loss:2.0409
#
# EPOCH[8] - STEP[210]
# Generator_loss:1.7068
# L1_loss:0.1976
# Discriminator_loss:0.4366
#
# EPOCH[8] - STEP[220]
# Generator_loss:1.4248
# L1_loss:0.1647
# Discriminator_loss:1.7084
#
# EPOCH[8] - STEP[230]
# Generator_loss:2.3288
# L1_loss:0.1692
# Discriminator_loss:0.4166
#
# EPOCH[8] - STEP[240]
# Generator_loss:2.1715
# L1_loss:0.1826
# Discriminator_loss:1.5495
#
# EPOCH[8] - STEP[250]
# Generator_loss:1.2328
# L1_loss:0.2057
# Discriminator_loss:0.4641
#
# EPOCH[9] - STEP[10]
# Generator_loss:2.7279
# L1_loss:0.1857
# Discriminator_loss:0.4058
#
# EPOCH[9] - STEP[20]
# Generator_loss:1.1933
# L1_loss:0.2001
# Discriminator_loss:0.5048
#
# EPOCH[9] - STEP[30]
# Generator_loss:1.3215
# L1_loss:0.2244
# Discriminator_loss:0.4216
#
# EPOCH[9] - STEP[40]
# Generator_loss:1.1042
# L1_loss:0.1915
# Discriminator_loss:1.8069
#
# EPOCH[9] - STEP[50]
# Generator_loss:0.6081
# L1_loss:0.1720
# Discriminator_loss:1.0040
#
# EPOCH[9] - STEP[60]
# Generator_loss:1.5716
# L1_loss:0.1870
# Discriminator_loss:1.3518
#
# EPOCH[9] - STEP[70]
# Generator_loss:1.0554
# L1_loss:0.1636
# Discriminator_loss:0.7265
#
# EPOCH[9] - STEP[80]
# Generator_loss:1.0733
# L1_loss:0.1872
# Discriminator_loss:0.5521
#
# EPOCH[9] - STEP[90]
# Generator_loss:1.2261
# L1_loss:0.1911
# Discriminator_loss:0.6067
#
# EPOCH[9] - STEP[100]
# Generator_loss:1.3508
# L1_loss:0.1573
# Discriminator_loss:0.5156
#
# EPOCH[9] - STEP[110]
# Generator_loss:0.4928
# L1_loss:0.1828
# Discriminator_loss:1.1469
#
# EPOCH[9] - STEP[120]
# Generator_loss:1.4330
# L1_loss:0.1958
# Discriminator_loss:0.3895
#
# EPOCH[9] - STEP[130]
# Generator_loss:1.2327
# L1_loss:0.1876
# Discriminator_loss:0.5344
#
# EPOCH[9] - STEP[140]
# Generator_loss:1.6739
# L1_loss:0.2233
# Discriminator_loss:0.2762
#
# EPOCH[9] - STEP[150]
# Generator_loss:0.2447
# L1_loss:0.1830
# Discriminator_loss:1.6954
#
# EPOCH[9] - STEP[160]
# Generator_loss:0.2362
# L1_loss:0.1540
# Discriminator_loss:1.9844
#
# EPOCH[9] - STEP[170]
# Generator_loss:2.1717
# L1_loss:0.1900
# Discriminator_loss:0.4096
#
# EPOCH[9] - STEP[180]
# Generator_loss:1.1393
# L1_loss:0.1800
# Discriminator_loss:0.9396
#
# EPOCH[9] - STEP[190]
# Generator_loss:0.7866
# L1_loss:0.1587
# Discriminator_loss:1.4261
#
# EPOCH[9] - STEP[200]
# Generator_loss:0.8080
# L1_loss:0.1671
# Discriminator_loss:1.0757
#
# EPOCH[9] - STEP[210]
# Generator_loss:0.9050
# L1_loss:0.1839
# Discriminator_loss:0.6553
#
# EPOCH[9] - STEP[220]
# Generator_loss:0.9092
# L1_loss:0.2069
# Discriminator_loss:0.6527
#
# EPOCH[9] - STEP[230]
# Generator_loss:1.6333
# L1_loss:0.1988
# Discriminator_loss:1.4579
#
# EPOCH[9] - STEP[240]
# Generator_loss:1.1236
# L1_loss:0.1734
# Discriminator_loss:0.5528
#
# EPOCH[9] - STEP[250]
# Generator_loss:1.9860
# L1_loss:0.1632
# Discriminator_loss:1.4199
#
# EPOCH[10] - STEP[10]
# Generator_loss:1.9721
# L1_loss:0.1752
# Discriminator_loss:1.5067
#
# EPOCH[10] - STEP[20]
# Generator_loss:1.1939
# L1_loss:0.1516
# Discriminator_loss:1.2159
#
# EPOCH[10] - STEP[30]
# Generator_loss:0.4253
# L1_loss:0.2201
# Discriminator_loss:1.4706
#
# EPOCH[10] - STEP[40]
# Generator_loss:1.8423
# L1_loss:0.1697
# Discriminator_loss:0.5334
#
# EPOCH[10] - STEP[50]
# Generator_loss:1.9687
# L1_loss:0.1653
# Discriminator_loss:1.5042
#
# EPOCH[10] - STEP[60]
# Generator_loss:1.3523
# L1_loss:0.1741
# Discriminator_loss:0.5986
#
# EPOCH[10] - STEP[70]
# Generator_loss:0.5214
# L1_loss:0.2126
# Discriminator_loss:1.0985
#
# EPOCH[10] - STEP[80]
# Generator_loss:0.7562
# L1_loss:0.2154
# Discriminator_loss:0.9422
#
# EPOCH[10] - STEP[90]
# Generator_loss:0.5322
# L1_loss:0.1806
# Discriminator_loss:1.8423
#
# EPOCH[10] - STEP[100]
# Generator_loss:2.4545
# L1_loss:0.1598
# Discriminator_loss:1.2767
#
# EPOCH[10] - STEP[110]
# Generator_loss:1.1134
# L1_loss:0.1935
# Discriminator_loss:0.5793
#
# EPOCH[10] - STEP[120]
# Generator_loss:1.4466
# L1_loss:0.2248
# Discriminator_loss:0.4199
#
# EPOCH[10] - STEP[130]
# Generator_loss:0.9449
# L1_loss:0.1982
# Discriminator_loss:0.6523
#
# EPOCH[10] - STEP[140]
# Generator_loss:1.3382
# L1_loss:0.1408
# Discriminator_loss:1.1463
#
# EPOCH[10] - STEP[150]
# Generator_loss:0.2615
# L1_loss:0.1949
# Discriminator_loss:1.6571
#
# EPOCH[10] - STEP[160]
# Generator_loss:0.8838
# L1_loss:0.1452
# Discriminator_loss:0.8830
#
# EPOCH[10] - STEP[170]
# Generator_loss:1.9200
# L1_loss:0.1786
# Discriminator_loss:0.6594
#
# EPOCH[10] - STEP[180]
# Generator_loss:0.6970
# L1_loss:0.1802
# Discriminator_loss:0.9636
#
# EPOCH[10] - STEP[190]
# Generator_loss:0.6984
# L1_loss:0.1938
# Discriminator_loss:1.2235
#
# EPOCH[10] - STEP[200]
# Generator_loss:1.1788
# L1_loss:0.1785
# Discriminator_loss:1.4553
#
# EPOCH[10] - STEP[210]
# Generator_loss:1.9234
# L1_loss:0.1874
# Discriminator_loss:0.2995
#
# EPOCH[10] - STEP[220]
# Generator_loss:2.9014
# L1_loss:0.1922
# Discriminator_loss:2.6420
#
# EPOCH[10] - STEP[230]
# Generator_loss:1.4150
# L1_loss:0.1628
# Discriminator_loss:0.7588
#
# EPOCH[10] - STEP[240]
# Generator_loss:2.0603
# L1_loss:0.1589
# Discriminator_loss:1.8744
#
# EPOCH[10] - STEP[250]
# Generator_loss:0.7933
# L1_loss:0.1959
# Discriminator_loss:0.8420
#
# EPOCH[11] - STEP[10]
# Generator_loss:1.4489
# L1_loss:0.1731
# Discriminator_loss:0.5050
#
# EPOCH[11] - STEP[20]
# Generator_loss:0.9429
# L1_loss:0.2085
# Discriminator_loss:0.6596
#
# EPOCH[11] - STEP[30]
# Generator_loss:0.8936
# L1_loss:0.1884
# Discriminator_loss:0.6855
#
# EPOCH[11] - STEP[40]
# Generator_loss:1.5104
# L1_loss:0.2074
# Discriminator_loss:0.3787
#
# EPOCH[11] - STEP[50]
# Generator_loss:1.3392
# L1_loss:0.1832
# Discriminator_loss:0.6395
#
# EPOCH[11] - STEP[60]
# Generator_loss:1.1529
# L1_loss:0.1627
# Discriminator_loss:0.8132
#
# EPOCH[11] - STEP[70]
# Generator_loss:0.4660
# L1_loss:0.1892
# Discriminator_loss:1.4031
#
# EPOCH[11] - STEP[80]
# Generator_loss:1.0467
# L1_loss:0.1801
# Discriminator_loss:1.5541
#
# EPOCH[11] - STEP[90]
# Generator_loss:0.8474
# L1_loss:0.1721
# Discriminator_loss:0.7316
#
# EPOCH[11] - STEP[100]
# Generator_loss:1.6558
# L1_loss:0.1876
# Discriminator_loss:0.4328
#
# EPOCH[11] - STEP[110]
# Generator_loss:1.8423
# L1_loss:0.1743
# Discriminator_loss:0.4667
#
# EPOCH[11] - STEP[120]
# Generator_loss:0.9139
# L1_loss:0.1875
# Discriminator_loss:0.6596
#
# EPOCH[11] - STEP[130]
# Generator_loss:1.1864
# L1_loss:0.1957
# Discriminator_loss:0.4780
#
# EPOCH[11] - STEP[140]
# Generator_loss:0.8855
# L1_loss:0.1752
# Discriminator_loss:1.0373
#
# EPOCH[11] - STEP[150]
# Generator_loss:1.6357
# L1_loss:0.1782
# Discriminator_loss:0.5341
#
# EPOCH[11] - STEP[160]
# Generator_loss:1.8622
# L1_loss:0.1682
# Discriminator_loss:1.0560
#
# EPOCH[11] - STEP[170]
# Generator_loss:0.5959
# L1_loss:0.2057
# Discriminator_loss:0.9519
#
# EPOCH[11] - STEP[180]
# Generator_loss:1.5864
# L1_loss:0.2002
# Discriminator_loss:0.5238
#
# EPOCH[11] - STEP[190]
# Generator_loss:1.6582
# L1_loss:0.1825
# Discriminator_loss:0.5192
#
# EPOCH[11] - STEP[200]
# Generator_loss:1.3299
# L1_loss:0.1654
# Discriminator_loss:0.5667
#
# EPOCH[11] - STEP[210]
# Generator_loss:2.8150
# L1_loss:0.2173
# Discriminator_loss:0.4756
#
# EPOCH[11] - STEP[220]
# Generator_loss:0.9973
# L1_loss:0.1699
# Discriminator_loss:1.4350
#
# EPOCH[11] - STEP[230]
# Generator_loss:0.6079
# L1_loss:0.1530
# Discriminator_loss:1.0045
#
# EPOCH[11] - STEP[240]
# Generator_loss:0.2742
# L1_loss:0.1777
# Discriminator_loss:1.9530
#
# EPOCH[11] - STEP[250]
# Generator_loss:1.7829
# L1_loss:0.1725
# Discriminator_loss:0.7554
#
# EPOCH[12] - STEP[10]
# Generator_loss:0.5463
# L1_loss:0.1814
# Discriminator_loss:1.3094
#
# EPOCH[12] - STEP[20]
# Generator_loss:0.5678
# L1_loss:0.1886
# Discriminator_loss:1.1332
#
# EPOCH[12] - STEP[30]
# Generator_loss:0.6491
# L1_loss:0.1541
# Discriminator_loss:0.9636
#
# EPOCH[12] - STEP[40]
# Generator_loss:1.0689
# L1_loss:0.1584
# Discriminator_loss:0.7334
#
# EPOCH[12] - STEP[50]
# Generator_loss:1.8669
# L1_loss:0.1544
# Discriminator_loss:1.8621
#
# EPOCH[12] - STEP[60]
# Generator_loss:0.8755
# L1_loss:0.1890
# Discriminator_loss:0.7370
#
# EPOCH[12] - STEP[70]
# Generator_loss:1.4455
# L1_loss:0.1742
# Discriminator_loss:0.4582
#
# EPOCH[12] - STEP[80]
# Generator_loss:1.6374
# L1_loss:0.1789
# Discriminator_loss:0.9457
#
# EPOCH[12] - STEP[90]
# Generator_loss:1.6012
# L1_loss:0.1664
# Discriminator_loss:0.6587
#
# EPOCH[12] - STEP[100]
# Generator_loss:1.4389
# L1_loss:0.1550
# Discriminator_loss:0.9022
#
# EPOCH[12] - STEP[110]
# Generator_loss:1.9939
# L1_loss:0.1988
# Discriminator_loss:1.1925
#
# EPOCH[12] - STEP[120]
# Generator_loss:0.6324
# L1_loss:0.1615
# Discriminator_loss:1.9217
#
# EPOCH[12] - STEP[130]
# Generator_loss:2.1807
# L1_loss:0.1626
# Discriminator_loss:1.2490
#
# EPOCH[12] - STEP[140]
# Generator_loss:1.7732
# L1_loss:0.1747
# Discriminator_loss:0.5799
#
# EPOCH[12] - STEP[150]
# Generator_loss:1.2223
# L1_loss:0.2084
# Discriminator_loss:0.5555
#
# EPOCH[12] - STEP[160]
# Generator_loss:1.7993
# L1_loss:0.1672
# Discriminator_loss:1.3968
#
# EPOCH[12] - STEP[170]
# Generator_loss:0.4780
# L1_loss:0.2383
# Discriminator_loss:1.1007
#
# EPOCH[12] - STEP[180]
# Generator_loss:1.0283
# L1_loss:0.1386
# Discriminator_loss:2.9985
#
# EPOCH[12] - STEP[190]
# Generator_loss:1.7742
# L1_loss:0.1630
# Discriminator_loss:0.5117
#
# EPOCH[12] - STEP[200]
# Generator_loss:1.1792
# L1_loss:0.1729
# Discriminator_loss:0.4621
#
# EPOCH[12] - STEP[210]
# Generator_loss:1.6097
# L1_loss:0.1858
# Discriminator_loss:0.4042
#
# EPOCH[12] - STEP[220]
# Generator_loss:1.2290
# L1_loss:0.1828
# Discriminator_loss:0.6911
#
# EPOCH[12] - STEP[230]
# Generator_loss:0.6232
# L1_loss:0.2337
# Discriminator_loss:0.9559
#
# EPOCH[12] - STEP[240]
# Generator_loss:0.8880
# L1_loss:0.1698
# Discriminator_loss:1.2074
#
# EPOCH[12] - STEP[250]
# Generator_loss:2.2458
# L1_loss:0.1891
# Discriminator_loss:0.2040
#
# EPOCH[13] - STEP[10]
# Generator_loss:2.1689
# L1_loss:0.1671
# Discriminator_loss:1.1035
#
# EPOCH[13] - STEP[20]
# Generator_loss:2.2244
# L1_loss:0.1575
# Discriminator_loss:1.0069
#
# EPOCH[13] - STEP[30]
# Generator_loss:0.6682
# L1_loss:0.1725
# Discriminator_loss:0.9712
#
# EPOCH[13] - STEP[40]
# Generator_loss:1.5327
# L1_loss:0.1970
# Discriminator_loss:0.6305
#
# EPOCH[13] - STEP[50]
# Generator_loss:1.3416
# L1_loss:0.1935
# Discriminator_loss:0.6607
#
# EPOCH[13] - STEP[60]
# Generator_loss:1.1290
# L1_loss:0.1677
# Discriminator_loss:0.5915
#
# EPOCH[13] - STEP[70]
# Generator_loss:0.8192
# L1_loss:0.1749
# Discriminator_loss:0.7934
#
# EPOCH[13] - STEP[80]
# Generator_loss:0.7323
# L1_loss:0.1780
# Discriminator_loss:0.8625
#
# EPOCH[13] - STEP[90]
# Generator_loss:1.5355
# L1_loss:0.1560
# Discriminator_loss:0.9033
#
# EPOCH[13] - STEP[100]
# Generator_loss:2.1701
# L1_loss:0.2218
# Discriminator_loss:0.5756
#
# EPOCH[13] - STEP[110]
# Generator_loss:0.3235
# L1_loss:0.1698
# Discriminator_loss:1.7526
#
# EPOCH[13] - STEP[120]
# Generator_loss:1.2360
# L1_loss:0.1712
# Discriminator_loss:0.5295
#
# EPOCH[13] - STEP[130]
# Generator_loss:1.1531
# L1_loss:0.1612
# Discriminator_loss:1.2104
#
# EPOCH[13] - STEP[140]
# Generator_loss:1.2008
# L1_loss:0.1652
# Discriminator_loss:1.2978
#
# EPOCH[13] - STEP[150]
# Generator_loss:0.3573
# L1_loss:0.1967
# Discriminator_loss:1.3288
#
# EPOCH[13] - STEP[160]
# Generator_loss:2.0155
# L1_loss:0.2081
# Discriminator_loss:0.2503
#
# EPOCH[13] - STEP[170]
# Generator_loss:0.9484
# L1_loss:0.1579
# Discriminator_loss:0.6513
#
# EPOCH[13] - STEP[180]
# Generator_loss:0.7389
# L1_loss:0.1870
# Discriminator_loss:0.7601
#
# EPOCH[13] - STEP[190]
# Generator_loss:0.8275
# L1_loss:0.1517
# Discriminator_loss:1.1502
#
# EPOCH[13] - STEP[200]
# Generator_loss:1.4688
# L1_loss:0.1797
# Discriminator_loss:0.4583
#
# EPOCH[13] - STEP[210]
# Generator_loss:1.2288
# L1_loss:0.1745
# Discriminator_loss:0.5165
#
# EPOCH[13] - STEP[220]
# Generator_loss:1.2849
# L1_loss:0.1557
# Discriminator_loss:0.6716
#
# EPOCH[13] - STEP[230]
# Generator_loss:1.4330
# L1_loss:0.1740
# Discriminator_loss:0.8949
#
# EPOCH[13] - STEP[240]
# Generator_loss:1.2209
# L1_loss:0.2046
# Discriminator_loss:0.5849
#
# EPOCH[13] - STEP[250]
# ...
# L1_loss:0.1775
# Discriminator_loss:1.1325
#
# EPOCH[26] - STEP[190]
# Generator_loss:1.6047
# L1_loss:0.1531
# Discriminator_loss:1.3468
#
# EPOCH[26] - STEP[200]
# Generator_loss:1.0187
# L1_loss:0.1863
# Discriminator_loss:0.6522
#
# EPOCH[26] - STEP[210]
# Generator_loss:0.9655
# L1_loss:0.1704
# Discriminator_loss:0.8879
#
# EPOCH[26] - STEP[220]
# Generator_loss:0.8667
# L1_loss:0.1691
# Discriminator_loss:0.7544
#
# EPOCH[26] - STEP[230]
# Generator_loss:1.2464
# L1_loss:0.1642
# Discriminator_loss:0.5567
#
# EPOCH[26] - STEP[240]
# Generator_loss:0.9065
# L1_loss:0.2100
# Discriminator_loss:0.6128
#
# EPOCH[26] - STEP[250]
# Generator_loss:0.9460
# L1_loss:0.1814
# Discriminator_loss:0.7085
#
# EPOCH[27] - STEP[10]
# Generator_loss:2.5615
# L1_loss:0.1798
# Discriminator_loss:1.3350
#
# EPOCH[27] - STEP[20]
# Generator_loss:0.6163
# L1_loss:0.1674
# Discriminator_loss:1.2311
#
# EPOCH[27] - STEP[30]
# Generator_loss:2.2164
# L1_loss:0.1818
# Discriminator_loss:0.2830
#
# EPOCH[27] - STEP[40]
# Generator_loss:1.3468
# L1_loss:0.1812
# Discriminator_loss:0.4580
#
# EPOCH[27] - STEP[50]
# Generator_loss:1.1044
# L1_loss:0.2029
# Discriminator_loss:0.5260
#
# EPOCH[27] - STEP[60]
# Generator_loss:1.5777
# L1_loss:0.1734
# Discriminator_loss:0.4805
#
# EPOCH[27] - STEP[70]
# Generator_loss:1.5464
# L1_loss:0.1581
# Discriminator_loss:1.1418
#
# EPOCH[27] - STEP[80]
# Generator_loss:2.0862
# L1_loss:0.1614
# Discriminator_loss:0.5011
#
# EPOCH[27] - STEP[90]
# Generator_loss:1.8740
# L1_loss:0.1814
# Discriminator_loss:0.4382
#
# EPOCH[27] - STEP[100]
# Generator_loss:0.2113
# L1_loss:0.1801
# Discriminator_loss:2.0899
#
# EPOCH[27] - STEP[110]
# Generator_loss:1.2788
# L1_loss:0.1640
# Discriminator_loss:0.6955
#
# EPOCH[27] - STEP[120]
# Generator_loss:1.1395
# L1_loss:0.1818
# Discriminator_loss:0.5072
#
# EPOCH[27] - STEP[130]
# Generator_loss:2.2109
# L1_loss:0.1351
# Discriminator_loss:2.5823
#
# EPOCH[27] - STEP[140]
# Generator_loss:0.6984
# L1_loss:0.1761
# Discriminator_loss:1.1794
#
# EPOCH[27] - STEP[150]
# Generator_loss:1.3033
# L1_loss:0.1577
# Discriminator_loss:2.9460
#
# EPOCH[27] - STEP[160]
# Generator_loss:0.3944
# L1_loss:0.1649
# Discriminator_loss:1.4312
#
# EPOCH[27] - STEP[170]
# Generator_loss:1.6452
# L1_loss:0.1749
# Discriminator_loss:0.4556
#
# EPOCH[27] - STEP[180]
# Generator_loss:1.7140
# L1_loss:0.1966
# Discriminator_loss:0.6009
#
# EPOCH[27] - STEP[190]
# Generator_loss:1.4361
# L1_loss:0.1632
# Discriminator_loss:1.4404
#
# EPOCH[27] - STEP[200]
# Generator_loss:0.4394
# L1_loss:0.1707
# Discriminator_loss:1.3937
#
# EPOCH[27] - STEP[210]
# Generator_loss:0.1327
# L1_loss:0.1466
# Discriminator_loss:2.5570
#
# EPOCH[27] - STEP[220]
# Generator_loss:1.0200
# L1_loss:0.1771
# Discriminator_loss:0.5723
#
# EPOCH[27] - STEP[230]
# Generator_loss:1.1113
# L1_loss:0.2075
# Discriminator_loss:0.4675
#
# EPOCH[27] - STEP[240]
# Generator_loss:0.8618
# L1_loss:0.1661
# Discriminator_loss:0.9497
#
# EPOCH[27] - STEP[250]
# Generator_loss:1.4258
# L1_loss:0.1796
# Discriminator_loss:0.9708
#
# EPOCH[28] - STEP[10]
# Generator_loss:0.8758
# L1_loss:0.2287
# Discriminator_loss:0.8003
#
# EPOCH[28] - STEP[20]
# Generator_loss:1.3782
# L1_loss:0.1847
# Discriminator_loss:0.4643
#
# EPOCH[28] - STEP[30]
# Generator_loss:1.2109
# L1_loss:0.1557
# Discriminator_loss:1.4109
#
# EPOCH[28] - STEP[40]
# Generator_loss:1.2392
# L1_loss:0.1473
# Discriminator_loss:1.1904
#
# EPOCH[28] - STEP[50]
# Generator_loss:1.0251
# L1_loss:0.1895
# Discriminator_loss:0.6129
#
# EPOCH[28] - STEP[60]
# Generator_loss:1.2267
# L1_loss:0.1440
# Discriminator_loss:0.9810
#
# EPOCH[28] - STEP[70]
# Generator_loss:1.8968
# L1_loss:0.1880
# Discriminator_loss:0.4123
#
# EPOCH[28] - STEP[80]
# Generator_loss:1.0504
# L1_loss:0.1806
# Discriminator_loss:0.8326
#
# EPOCH[28] - STEP[90]
# Generator_loss:1.3142
# L1_loss:0.1737
# Discriminator_loss:1.4037
#
# EPOCH[28] - STEP[100]
# Generator_loss:1.0502
# L1_loss:0.1945
# Discriminator_loss:0.6004
#
# EPOCH[28] - STEP[110]
# Generator_loss:1.0613
# L1_loss:0.2065
# Discriminator_loss:0.6010
#
# EPOCH[28] - STEP[120]
# Generator_loss:0.9043
# L1_loss:0.1697
# Discriminator_loss:1.1164
#
# EPOCH[28] - STEP[130]
# Generator_loss:1.1774
# L1_loss:0.1669
# Discriminator_loss:0.8308
#
# EPOCH[28] - STEP[140]
# Generator_loss:1.2099
# L1_loss:0.1867
# Discriminator_loss:0.5504
#
# EPOCH[28] - STEP[150]
# Generator_loss:0.6981
# L1_loss:0.1726
# Discriminator_loss:0.9059
#
# EPOCH[28] - STEP[160]
# Generator_loss:0.9257
# L1_loss:0.1779
# Discriminator_loss:0.9239
#
# EPOCH[28] - STEP[170]
# Generator_loss:2.4366
# L1_loss:0.1702
# Discriminator_loss:0.4818
#
# EPOCH[28] - STEP[180]
# Generator_loss:1.8273
# L1_loss:0.1653
# Discriminator_loss:0.3834
#
# EPOCH[28] - STEP[190]
# Generator_loss:2.4752
# L1_loss:0.1782
# Discriminator_loss:1.1175
#
# EPOCH[28] - STEP[200]
# Generator_loss:1.0060
# L1_loss:0.2183
# Discriminator_loss:0.5430
#
# EPOCH[28] - STEP[210]
# Generator_loss:0.4076
# L1_loss:0.1968
# Discriminator_loss:1.3210
#
# EPOCH[28] - STEP[220]
# Generator_loss:1.8163
# L1_loss:0.1815
# Discriminator_loss:0.3162
#
# EPOCH[28] - STEP[230]
# Generator_loss:1.4723
# L1_loss:0.1909
# Discriminator_loss:0.4826
#
# EPOCH[28] - STEP[240]
# Generator_loss:0.3670
# L1_loss:0.1687
# Discriminator_loss:1.5891
#
# EPOCH[28] - STEP[250]
# Generator_loss:1.0227
# L1_loss:0.1591
# Discriminator_loss:0.6378
#
# EPOCH[29] - STEP[10]
# Generator_loss:2.0753
# L1_loss:0.1958
# Discriminator_loss:0.2471
#
# EPOCH[29] - STEP[20]
# Generator_loss:1.1260
# L1_loss:0.1886
# Discriminator_loss:0.6767
#
# EPOCH[29] - STEP[30]
# Generator_loss:1.6679
# L1_loss:0.1700
# Discriminator_loss:0.9254
#
# EPOCH[29] - STEP[40]
# Generator_loss:1.2252
# L1_loss:0.1650
# Discriminator_loss:1.1789
#
# EPOCH[29] - STEP[50]
# Generator_loss:2.3121
# L1_loss:0.1795
# Discriminator_loss:0.7377
#
# EPOCH[29] - STEP[60]
# Generator_loss:1.9623
# L1_loss:0.1786
# Discriminator_loss:0.2758
#
# EPOCH[29] - STEP[70]
# Generator_loss:0.6240
# L1_loss:0.2197
# Discriminator_loss:0.8580
#
# EPOCH[29] - STEP[80]
# Generator_loss:1.5876
# L1_loss:0.2097
# Discriminator_loss:0.3033
#
# EPOCH[29] - STEP[90]
# Generator_loss:2.0298
# L1_loss:0.1588
# Discriminator_loss:0.9760
#
# EPOCH[29] - STEP[100]
# Generator_loss:1.6769
# L1_loss:0.1853
# Discriminator_loss:2.7190
#
# EPOCH[29] - STEP[110]
# Generator_loss:1.7452
# L1_loss:0.1685
# Discriminator_loss:1.7631
#
# EPOCH[29] - STEP[120]
# Generator_loss:1.0106
# L1_loss:0.2042
# Discriminator_loss:0.6299
#
# EPOCH[29] - STEP[130]
# Generator_loss:1.3175
# L1_loss:0.1880
# Discriminator_loss:0.9223
#
# EPOCH[29] - STEP[140]
# Generator_loss:0.7192
# L1_loss:0.1986
# Discriminator_loss:1.0623
#
# EPOCH[29] - STEP[150]
# Generator_loss:0.8777
# L1_loss:0.1728
# Discriminator_loss:0.8748
#
# EPOCH[29] - STEP[160]
# Generator_loss:1.6867
# L1_loss:0.1523
# Discriminator_loss:0.9358
#
# EPOCH[29] - STEP[170]
# Generator_loss:0.6113
# L1_loss:0.1725
# Discriminator_loss:1.0126
#
# EPOCH[29] - STEP[180]
# Generator_loss:1.3743
# L1_loss:0.1793
# Discriminator_loss:0.4778
#
# EPOCH[29] - STEP[190]
# Generator_loss:1.8412
# L1_loss:0.1596
# Discriminator_loss:0.5223
#
# EPOCH[29] - STEP[200]
# Generator_loss:0.9097
# L1_loss:0.1530
# Discriminator_loss:1.0173
#
# EPOCH[29] - STEP[210]
# Generator_loss:1.9524
# L1_loss:0.2091
# Discriminator_loss:0.2652
#
# EPOCH[29] - STEP[220]
# Generator_loss:2.2084
# L1_loss:0.2058
# Discriminator_loss:0.1765
#
# EPOCH[29] - STEP[230]
# Generator_loss:1.6818
# L1_loss:0.1649
# Discriminator_loss:0.5418
#
# EPOCH[29] - STEP[240]
# Generator_loss:0.7385
# L1_loss:0.1877
# Discriminator_loss:0.9513
#
# EPOCH[29] - STEP[250]
# Generator_loss:0.6662
# L1_loss:0.1780
# Discriminator_loss:1.0135
#
# EPOCH[30] - STEP[10]
# Generator_loss:1.9528
# L1_loss:0.1613
# Discriminator_loss:0.7764
#
# EPOCH[30] - STEP[20]
# Generator_loss:1.7321
# L1_loss:0.1402
# Discriminator_loss:1.9820
#
# EPOCH[30] - STEP[30]
# Generator_loss:1.4025
# L1_loss:0.1810
# Discriminator_loss:0.5080
#
# EPOCH[30] - STEP[40]
# Generator_loss:1.2248
# L1_loss:0.2061
# Discriminator_loss:0.4695
#
# EPOCH[30] - STEP[50]
# Generator_loss:1.3204
# L1_loss:0.1857
# Discriminator_loss:0.5649
#
# EPOCH[30] - STEP[60]
# Generator_loss:1.8369
# L1_loss:0.1727
# Discriminator_loss:0.3411
#
# EPOCH[30] - STEP[70]
# Generator_loss:1.4398
# L1_loss:0.2223
# Discriminator_loss:0.3159
#
# EPOCH[30] - STEP[80]
# Generator_loss:1.2788
# L1_loss:0.1674
# Discriminator_loss:1.4299
#
# EPOCH[30] - STEP[90]
# Generator_loss:1.7190
# L1_loss:0.1716
# Discriminator_loss:0.2624
#
# EPOCH[30] - STEP[100]
# Generator_loss:1.4444
# L1_loss:0.1607
# Discriminator_loss:0.8030
#
# EPOCH[30] - STEP[110]
# Generator_loss:3.8531
# L1_loss:0.1743
# Discriminator_loss:0.4968
#
# EPOCH[30] - STEP[120]
# Generator_loss:1.2613
# L1_loss:0.1719
# Discriminator_loss:1.7096
#
# EPOCH[30] - STEP[130]
# Generator_loss:2.1280
# L1_loss:0.1670
# Discriminator_loss:0.5160
#
# EPOCH[30] - STEP[140]
# Generator_loss:1.5886
# L1_loss:0.1884
# Discriminator_loss:0.3783
#
# EPOCH[30] - STEP[150]
# Generator_loss:0.9849
# L1_loss:0.1655
# Discriminator_loss:0.7648
#
# EPOCH[30] - STEP[160]
# Generator_loss:1.0921
# L1_loss:0.1752
# Discriminator_loss:0.6576
#
# EPOCH[30] - STEP[170]
# Generator_loss:1.1004
# L1_loss:0.2113
# Discriminator_loss:0.7962
#
# EPOCH[30] - STEP[180]
# Generator_loss:1.4580
# L1_loss:0.1577
# Discriminator_loss:0.5973
#
# EPOCH[30] - STEP[190]
# Generator_loss:1.0822
# L1_loss:0.1635
# Discriminator_loss:0.7988
#
# EPOCH[30] - STEP[200]
# Generator_loss:2.2670
# L1_loss:0.1579
# Discriminator_loss:0.7029
#
# EPOCH[30] - STEP[210]
# Generator_loss:0.8920
# L1_loss:0.1995
# Discriminator_loss:0.6575
#
# EPOCH[30] - STEP[220]
# Generator_loss:0.8266
# L1_loss:0.1627
# Discriminator_loss:1.1721
#
# EPOCH[30] - STEP[230]
# Generator_loss:2.4096
# L1_loss:0.2103
# Discriminator_loss:0.2742
#
# EPOCH[30] - STEP[240]
# Generator_loss:2.3526
# L1_loss:0.1829
# Discriminator_loss:0.3185
#
# EPOCH[30] - STEP[250]
# Generator_loss:0.5656
# L1_loss:0.1652
# Discriminator_loss:1.1633

# %%
test_ind = 1

f = data_path + os.listdir(data_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))
plt.show();

# %% [markdown]
# # 회고

# %% [markdown]
# CGAN은 기존에 GAN이 generator에 noise와 discriminator에 img만 사용했다면 조건부 데이터를 추가해줘서 GAN보다 더 정확한 이미지를 얻을 수 있었습니다. 전에 했던 GAN은 epoch를 500회 이상 넣어도 정확한 이미지가 안나왔었는데 CGAN은 라벨 값인 condition을 추가해줌으로써 epoch가 30밖에 안돌리고도 좋은 이미지를 얻을 수 있었습니다. 기존 데이터의 위치가 이미지와 스케치 위치가 반대로 되어있어서 두 개의 위치를 바꿔줌으로써 원하는 결과를 얻었습니다.
