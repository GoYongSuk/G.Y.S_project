# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# <img src="https://i.postimg.cc/1R2d17XR/logo-800-47024e2aeaaa8651c172ba883264dd43.png" alt="Italian Trulli">

# %% [markdown]
# ![League of Leagend](https://upload2.inven.co.kr/upload/2016/11/22/bbs/i12459752821.gif)

# %% [markdown]
# ![League of Leagend](https://blog.kakaocdn.net/dn/t9yr0/btrvGYK9d7M/rFAZy3GyImdDzMJEUrO8Y1/img.gif)

# %% [markdown]
# - **리그 오브 레전드란?**
#
#   - 리그 오브 레전드는 강력한 챔피언 5명으로 구성된 양 팀이 서로의 기지를 파괴하기 위해 치열한 사투를 벌이는 전략 게임입니다. 140여 명의 챔피언 중 하나를 선택해 화려한 플레이를 펼치며 적을 처치하고 포탑을 파괴해 승리를 쟁취하세요.
#
# - **기지 파괴하기**
#
#   - 넥서스는 양 팀 기지의 심장부입니다. 적의 넥서스를 먼저 파괴하는 팀이 게임에서 승리합니다.
#
# - **공격로 장악하기**
#
#   - 적팀 넥서스에 도달하려면 최소 1개의 공격로를 장악해야 합니다. 공격로에는 포탑과 억제기라는 방어용 구조물이 있습니다. 각 공격로에는 3개의 포탑과 1개의 억제기가 있으며, 넥서스는 2개의 포탑이 지키고 있습니다.
#
# - **정글 둘러보기**
#
#   - 공격로 사이에 있는 정글에는 중립 몬스터와 정글 식물이 살고 있습니다. 가장 중요한 몬스터는 내셔 남작과 드래곤입니다. 이 유닛을 처치하면 팀 전체가 고유의 이로운 효과를 얻어 게임의 승세를 뒤집을 수도 있습니다.
#
# - **공격로 선택하기**
#
#   - 게임에서 권장하는 팀 구성 역할군은 5가지입니다. 공격로마다 어울리는 챔피언과 역할군이 있습니다. 모두 플레이해 보거나 원하는 공격로를 선택하세요.
#
# - **챔피언 강화하기**
#
#   - 챔피언은 게임이 진행되는 동안 경험치를 얻어 레벨을 올리고 골드로 강력한 아이템을 구매해 성장합니다. 이 두가지에 집중해야 적팀을 압도하고 기지를 파괴할 수 있습니다.
#
# - **스킬 사용하기**
#
#   - 챔피언은 5개의 주요 스킬과 2개의 소환사 주문을 사용할 수 있으며, 한 번에 최대 7개의 아이템을 소지할 수 있습니다. 챔피언에게 가장 어울리는 스킬 순서, 소환사 주문, 아이템 빌드를 이용해 아군에게 도움이 되는 팀원이 되어 보세요.
#
#
# - <a href="https://www.leagueoflegends.com/ko-kr/how-to-play/?_gl=1*shrqvs*_ga*MTkwNzMyMDQwLjE2NDY2NzM2OTM.*_ga_FXBJE5DEDD*MTY0NjY3NTg3Mi4yLjEuMTY0NjY3NTk5Ni42MA..">League of Legends Korea Official Website</a>
#
# <br>
#
# ![League of Leagend](https://blog.kakaocdn.net/dn/z2ec4/btrvxlgxaTO/JOXxKKCO4uBEDW1eikI491/img.gif)

# %% [markdown]
# ## 랭크 시스템
# 소환사들의 티어 변동에 영향을 주는 게임으로, 2018 시즌까지는 브론즈/실버/골드/플래티넘/다이아몬드/마스터/챌린저의 티어가 있었고 브론즈부터 다이아몬드 티어까지는 각각의 티어를 세분화한 단계가 1단계(가장 상위)부터 5단계(가장 하위)까지 있었다. 2019 시즌부터는 아이언/브론즈/실버/골드/플래티넘/다이아몬드/마스터/그랜드마스터/챌린저로 구분되며, 아이언부터 다이아몬드 티어까지의 단계 구분이 4단계로 줄어들었다. 랭크 게임 플레이 조건은 기존의 만렙이었던 30레벨 이상이고, 자신이 직접 소유한 챔피언 20개 이상이다.
# <br>
# <br>
# ![League of Leagend 티어표](https://mblogthumb-phinf.pstatic.net/MjAxOTEwMDFfMjgx/MDAxNTY5OTExNDIxNzE2.OehoimCbvY51RxSW_wwuTvEkR8lQ2RZuUSFsLknNyeog.iKM82LtCSNF1i9E2cfD6cB3DrYk90iWxiZUEfr3Gk5sg.PNG.mochazin/%EB%A1%A4_%ED%8B%B0%EC%96%B4_%EC%88%9C%EC%9C%84_%EB%B0%8F_%EB%B6%84%ED%8F%AC.png?type=w800)
#
# <a href="https://leagueoflegends.fandom.com/wiki/League_of_Legends_Wiki">League of Legends Wiki</a>

# %% [markdown]
# <br>

# %% [markdown]
# ## 리그오브레전드 데이터셋

# %% [markdown]
# https://www.kaggle.com/bobbyscience/league-of-legends-diamond-ranked-games-10-min/version/1

# %% [markdown]
# <img src="https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FbV1Yqj%2FbtrvEFSSgyh%2FbAacKffyFOtMKOGBKItnQ0%2Fimg.png "  width="600" height="400">
#
# <br>
#
# - 이 데이터셋은 다이아몬드 구간부터 마스터 구간 사이의 게임 시작 10분 후의 데이터 입니다. 경기 10분 후 데이터에는 팀당 19개의 feature(총 38개의 feature)가 포함되어 있습니다.
#
# - blueWins 열은 목표값(예측하려는 값)입니다. 값이 1이면 파란색 팀이 이겼다는 의미이고, 그렇지 않으면 0입니다.
#
# - 결측값이 없습니다.

# %% [markdown]
# <br>

# %% [markdown]
# ## LOL data EDA
#
# 0. gameId : 게임 넘버링 (게임 한 판)
# 1. blueWins : 블루팀이 이기면 1, 레드팀이 이기면 0
# 2. blueWardsPlaced : 블루팀이 와드를 설치한 개수
# 3. blueWardsDestroyed : 블루팀이 파괴한 와드의 개수
# 4. blueFirstBlood : 블루팀이 첫 번째 킬을 성공하면 1, 아니면 0
# 5. blueKills : 블루팀 킬 수
# 6. blueDeaths : 블루팀이 죽은 수
# 7. blueAssists : 블루팀 어시스트 수
# 8. blueEliteMonsters : 블루팀이 처치한 엘리트 몬스터 수
# 9. blueDragons : 블루팀이 처치한 용의 수
# 10. blueHeralds : 블루팀이 처치한 협곡의 전령의 수
# 11. blueTowersDestroyed : 블루팀이 부신 타워의 수
# 12. blueTotalGold : 블루팀이 획득한 골드
# 13. blueAvgLevel : 블루팀의 평균 레벨
# 14. blueTotalExperience : 블루팀의 전체 경험치
# 15. blueTotalMinionsKilled : 블루팀의 미니언 처치 수
# 16. blueTotalJungleMinionsKilled : 블루팀에서 처치한 정글몹 수
# 17. blueGoldDiff : 블루팀과 레드팀의 골드차이
# 18. blueExperienceDiff : 블루팀과 레드팀의 경험치 차이
# 19. blueCSPerMin : 블루팀의 분당 CS
# 20. blueGoldPerMin : 블루팀의 분당 Gold
# 21. redWardsPlaced : 레드팀이 와드를 설치한 개수
# 22. redWardsDestroyed : 레드팀이 부신 타워의 수
# 23. redFirstBlood : 레드팀이 첫 번째 킬을 성공하면 1, 아니면 0
# 24. redKills : 레드팀 킬 수
# 25. redDeaths : 레드팀이 죽은 수
# 26. redAssists : 레드팀 어시스트 수
# 27. redEliteMonsters : 레드팀이 처치한 엘리트 몬스터 수
# 28. redDragons : 레드팀이 처치한 용의 수
# 29. redHeralds : 레드팀이 처치한 협곡의 전령의 수
# 30. redTowersDestroyed : 레드팀이 부신 타워의 수
# 31. redTotalGold : 레드팀이 획득한 골드
# 32. redAvgLevel : 레드팀의 평균 레벨
# 33. redTotalExperience : 레드팀의 전체 경험치
# 34. redTotalMinionsKilled : 레드팀의 미니언 처치 수
# 35. redTotalJungleMinionsKilled : 레드팀에서 처치한 정글몹 수
# 36. redGoldDiff : 레드팀과 블루팀의 골드차이
# 37. redExperienceDiff : 레드팀과 블루팀의 경험치 차이
# 38. redCSPerMin : 레드팀의 분당 CS
# 39. redGoldPerMin : 레드팀의 분당 Gold

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import roc_curve

# %%
path = '/content/drive/MyDrive/kaggle/LOL/high_diamond_ranked_10min.csv'

data = pd.read_csv(path)
oriData = data.copy()
data.sample(5)
# Out:
#           gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  \
# 9518  4522494083         1               15                   3
# 5703  4427502264         1               17                   1
# 2137  4515879923         0               14                   4
# 3230  4523465477         0               10                   3
# 4491  4422174919         1               14                   2
#
#       blueFirstBlood  blueKills  blueDeaths  blueAssists  blueEliteMonsters  \
# 9518               1         12           5           13                  0
# 5703               0          9           3            9                  1
# 2137               1          5          11            7                  1
# 3230               0          2           5            2                  0
# 4491               0          0           3            0                  0
#
#       blueDragons  ...  redTowersDestroyed  redTotalGold  redAvgLevel  \
# ...

# %% [markdown]
# 데이터 columns 확인

# %%
print(data.columns)
print('Columns의 개수: ',str(len(data.columns))+'개')
# Out:
# Index(['gameId', 'blueWins', 'blueWardsPlaced', 'blueWardsDestroyed',
#        'blueFirstBlood', 'blueKills', 'blueDeaths', 'blueAssists',
#        'blueEliteMonsters', 'blueDragons', 'blueHeralds',
#        'blueTowersDestroyed', 'blueTotalGold', 'blueAvgLevel',
#        'blueTotalExperience', 'blueTotalMinionsKilled',
#        'blueTotalJungleMinionsKilled', 'blueGoldDiff', 'blueExperienceDiff',
#        'blueCSPerMin', 'blueGoldPerMin', 'redWardsPlaced', 'redWardsDestroyed',
#        'redFirstBlood', 'redKills', 'redDeaths', 'redAssists',
#        'redEliteMonsters', 'redDragons', 'redHeralds', 'redTowersDestroyed',
#        'redTotalGold', 'redAvgLevel', 'redTotalExperience',
#        'redTotalMinionsKilled', 'redTotalJungleMinionsKilled', 'redGoldDiff',
#        'redExperienceDiff', 'redCSPerMin', 'redGoldPerMin'],
#       dtype='object')
# Columns의 개수:  40개

# %% [markdown]
# ### 데이터 결측치 확인

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9879 entries, 0 to 9878
# Data columns (total 40 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   gameId                        9879 non-null   int64
#  1   blueWins                      9879 non-null   int64
#  2   blueWardsPlaced               9879 non-null   int64
#  3   blueWardsDestroyed            9879 non-null   int64
#  4   blueFirstBlood                9879 non-null   int64
#  5   blueKills                     9879 non-null   int64
#  6   blueDeaths                    9879 non-null   int64
#  7   blueAssists                   9879 non-null   int64
#  8   blueEliteMonsters             9879 non-null   int64
#  9   blueDragons                   9879 non-null   int64
#  10  blueHeralds                   9879 non-null   int64
#  11  blueTowersDestroyed           9879 non-null   int64
#  12  blueTotalGold                 9879 non-null   int64
# ...

# %% [markdown]
# ## 타겟 데이터 'blueWins' 분석

# %%
palette=['#FF3500',"#0059FF"]
data["Wins"] = data.blueWins.map({0:"RedWin", 1:"BlueWin"})
sns.catplot(data=data, x="Wins", palette=palette, kind="count");

# %%
data.blueWins.value_counts()
# Out:
# 0    4949
# 1    4930
# Name: blueWins, dtype: int64

# %%
print(f'Blue Team 승률: %{round(len(data[data["blueWins"]==1]) / len(data),2) * 100} win rate.')
print("-"*30)
print(f'Red Team  승률: %{round(len(data[data["blueWins"]==0]) / len(data),2) * 100} win rate.')
# Out:
# Blue Team 승률: %50.0 win rate.
# ------------------------------
# Red Team  승률: %50.0 win rate.

# %% [markdown]
# <br>

# %% [markdown]
# # 데이터 분석(EDA), Feature

# %% [markdown]
# ## FirstBlood

# %%
data["BlueFirstBlood"] = data.blueFirstBlood.map({0:"Red", 1:"Blue"})
data["RedFirstBlood"] = data.redFirstBlood.map({0:"Red", 1:"Blue"})

fig, ax = plt.subplots(ncols=2, figsize=(13,5), dpi=100)
sns.countplot(data=data, x="BlueFirstBlood", hue="Wins", palette=palette[::-1], ax=ax[0])
sns.countplot(data=data, x="RedFirstBlood", hue="Wins", palette=palette, ax=ax[1])

plt.tight_layout()

# %%
print(f'블루팀이 FirstBlood를 했을 때, 블루팀의 승률: %{round(len(data[(data["blueFirstBlood"]==1) & data["blueWins"]==1]) / len(data[data["blueFirstBlood"]==1]) * 100,2)}')
print(f'레드팀이 FirstBlood를 했을 때, 레드팀의 승률: %{round(len(data[(data["redFirstBlood"]==1) & (data["blueWins"]==0)]) / len(data[data["redFirstBlood"]==1]) * 100,2)}')
# Out:
# 블루팀이 FirstBlood를 했을 때, 블루팀의 승률: %59.9
# 레드팀이 FirstBlood를 했을 때, 레드팀의 승률: %60.28

# %% [markdown]
# <br>

# %% [markdown]
# ## Kills

# %%
fig, ax = plt.subplots(ncols=2, figsize=(10,5), dpi=100)
b = sns.histplot(data=data, x="blueKills",bins=20, color=palette[1], ax=ax[0])
r = sns.histplot(data=data, x="redKills", bins=20, color=palette[0], ax=ax[1])

b.set(xlabel=None)
r.set(xlabel=None)
b.set_title("BlueKills")
r.set_title("RedKills")

plt.tight_layout()

# %% [markdown]
# <br>

# %% [markdown]
# ## Deaths

# %%
fig, ax = plt.subplots(ncols=2, figsize=(10,5), dpi=100)
b = sns.histplot(data=data, x="blueDeaths",bins=20, color=palette[1], ax=ax[0])
r = sns.histplot(data=data, x="redDeaths", bins=20, color=palette[0], ax=ax[1])

b.set(xlabel=None)
r.set(xlabel=None)
b.set_title("BlueDeaths")
r.set_title("RedDeaths")

plt.tight_layout()

# %% [markdown]
# <br>

# %% [markdown]
# ## Assists

# %%
fig, ax = plt.subplots(ncols=2, figsize=(10,5), dpi=100)
b = sns.histplot(data=data, x="blueAssists", bins=20, color=palette[1], ax=ax[0])
r = sns.histplot(data=data, x="redAssists", bins=20, color=palette[0], ax=ax[1])

b.set(xlabel=None)
r.set(xlabel=None)
b.set_title("BlueAssists")
r.set_title("RedAssists")

plt.tight_layout()

# %% [markdown]
# <br>

# %% [markdown]
# ## GoldDiff + TotalGold
# <img src="https://i.postimg.cc/Z5zHDQcG/4e0c55dcd8468bb3076e149cd084ed99.jpg" align="right" hspace=50 width="300" height="200">
#
# 골드는 리그 오브 레전드의 게임 내 화폐입니다. 이것은 챔피언들에게 보너스 통계와 능력을 제공하는 샵에서 아이템을 구입하는데 사용되며, 이는 결국 챔피언들이 경기를 진행하면서 그들의 힘을 키우는 주요 방법 중 하나입니다.
#
# 게임 시작 시 챔피언에게는 플레이 중인 맵에 따라 출발 골드가 주어지며, 다양한 수단을 통해 더 많은 골드를 받을 수 있습니다.
#
# <BR CLEAR=”left” />
#
# <a href="https://leagueoflegends.fandom.com/wiki/League_of_Legends_Wiki">League of Legends Wiki</a>

# %% [markdown]
# <br>

# %%
fig, ax = plt.subplots(ncols=2, figsize=(10,5), dpi=100)
sns.barplot(x=data[data["blueGoldDiff"]>0]["blueWins"].map({1:"Win", 0:"Lose"}).value_counts().index, y=data[data["blueGoldDiff"]>0]["blueWins"].map({1:"Win", 0:"Lose"}).value_counts().values, ax=ax[0], palette=palette[::-1])
sns.barplot(x=data[data["redGoldDiff"]>0]["blueWins"].map({0:"Win", 1:"Lose"}).value_counts().index, y=data[data["redGoldDiff"]>0]["blueWins"].map({0:"Win", 1:"Lose"}).value_counts().values, ax=ax[1], palette=palette)

ax[0].set_title("Blue Win When Blue Has Gold Advantage")
ax[1].set_title("Red Win When Red Has Gold Advantage")

plt.tight_layout()

# %%
fig, ax = plt.subplots(ncols=2, figsize=(8,4), dpi=100)

b = sns.histplot(data=data, x="blueTotalGold", bins=25, ax=ax[0], color=palette[1])
r = sns.histplot(data=data, x="redTotalGold", bins=25, ax=ax[1], color=palette[0])

plt.suptitle("TotalGold", va='baseline')

b.set(xlabel='BlueTotalGold')
r.set(xlabel='RedTotalGold')

plt.tight_layout()

# %% [markdown]
# <br>

# %% [markdown]
# ## ExperienceDiff

# %%
fig, ax = plt.subplots(ncols=2, figsize=(10,5), dpi=100)
sns.barplot(x=data[data["blueExperienceDiff"]>0]["blueWins"].map({1:"Win", 0:"Lose"}).value_counts().index, y=data[data["blueExperienceDiff"]>0]["blueWins"].map({1:"Win", 0:"Lose"}).value_counts().values, ax=ax[0], palette=palette[::-1])
sns.barplot(x=data[data["redExperienceDiff"]>0]["blueWins"].map({0:"Win", 1:"Lose"}).value_counts().index, y=data[data["redExperienceDiff"]>0]["blueWins"].map({0:"Win", 1:"Lose"}).value_counts().values, ax=ax[1], palette=palette)

ax[0].set_title("Blue Win When Blue Has Experience Advantage")
ax[1].set_title("Red Win When Red Has Experience Advantage")

plt.tight_layout()

# %%
print(f'Blue Team 경험치 차이: +: %{round(len(data[data["blueExperienceDiff"]>0]) / len(data),2) * 100},   -: %{round(len(data[data["blueExperienceDiff"]<=0]) / len(data),2) * 100}.')
print("-"*45)
print(f'Red Team  경험치 차이: +: %{round(len(data[data["redExperienceDiff"]>0]) / len(data),2) * 100},   -: %{round(len(data[data["redExperienceDiff"]<=0]) / len(data),2) * 100}.')
# Out:
# Blue Team 경험치 차이: +: %49.0,   -: %51.0.
# ---------------------------------------------
# Red Team  경험치 차이: +: %51.0,   -: %49.0.

# %% [markdown]
# <br>

# %% [markdown]
# ## Experience + AvgLevel

# %%
fig, ax = plt.subplots(ncols=2, figsize=(8,4), dpi=100)

g = sns.histplot(data=data, x="blueTotalExperience", bins=25, ax=ax[0], color=palette[1])
j = sns.histplot(data=data, x="redTotalExperience", bins=25, ax=ax[1], color=palette[0])

plt.suptitle("Total Experience", va='baseline')

g.set(xlabel="BlueTotalExperience")
j.set(xlabel="RedTotalExperience")

plt.tight_layout()

# %%
print(f'블루팀이 이길 때, 블루팀 전체 경험치의 평균: {round(data[data["blueWins"]==1]["blueTotalExperience"].mean(),2)}')
print(f'레드팀이 이길 때, 레드팀 전체 경험치의 평균: {round(data[data["blueWins"]==0]["redTotalExperience"].mean(),2)}')
print('-'*58)
print(f'블루팀이 질 때, 블루팀 전체 경험치의 평균: {round(data[data["blueWins"]==0]["blueTotalExperience"].mean(),2)}')
print(f'레드팀이 질 때, 레드팀 전체 경험치의 평균: {round(data[data["blueWins"]==1]["redTotalExperience"].mean(),2)}')
# Out:
# 블루팀이 이길 때, 블루팀 전체 경험치의 평균: 18404.58
# 레드팀이 이길 때, 레드팀 전체 경험치의 평균: 18425.37
# ----------------------------------------------------------
# 블루팀이 질 때, 블루팀 전체 경험치의 평균: 17453.47
# 레드팀이 질 때, 레드팀 전체 경험치의 평균: 17496.3

# %% [markdown]
# ### AvgLevel

# %%
print(f'블루팀이 이길 때, 블루팀 전체 평균 레벨 : {round(data[data["blueWins"]==1]["blueAvgLevel"].mean(),2)}')
print(f'레드팀이 이길 때, 레드팀 전체 평균 레벨: {round(data[data["blueWins"]==0]["redAvgLevel"].mean(),2)}')
print('-'*58)
print(f'블루팀이 질 때, 블루팀 전체 평균 레벨: {round(data[data["blueWins"]==0]["blueAvgLevel"].mean(),2)}')
print(f'레드팀이 질 때, 레드팀 전체 평균 레벨: {round(data[data["blueWins"]==1]["redAvgLevel"].mean(),2)}')
# Out:
# 블루팀이 이길 때, 블루팀 전체 평균 레벨 : 7.03
# 레드팀이 이길 때, 레드팀 전체 평균 레벨: 7.03
# ----------------------------------------------------------
# 블루팀이 질 때, 블루팀 전체 평균 레벨: 6.81
# 레드팀이 질 때, 레드팀 전체 평균 레벨: 6.82

# %% [markdown]
# 블루팀과 레드팀이 이기고 질 때 획득하는 팀원 전체의 경험치 차이가 거의 없습니다. League of Legend는 잘하는 사람 한 두명이 게임을 캐리할 수 있기 때문에 전체 경험치보다는 한 명이 획득하는 경험치나 레벨 데이터를 수집해서 각 라인별로 어디 라인이 좀 더 영향력이 있는지 분석하는 것이 좋을 것 같습니다. 현재 데이터 셋에는 개개인이 획득하는 경험치나 레벨이 없기 때문에 위에서 말한 내용에 대해서 분석할 수 없었습니다.

# %% [markdown]
# <br>

# %% [markdown]
# ## EliteMonsters

# %%
data["blueEliteMonsters"].head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0
# Name: blueEliteMonsters, dtype: int64

# %%
data["redEliteMonsters"].head()
# Out:
# 0    0
# 1    2
# 2    0
# 3    0
# 4    1
# Name: redEliteMonsters, dtype: int64

# %% [markdown]
# 기존에 EliteMonsters를 레드와 블루라고 가정했을 때 10분 동안 2마리 이하로 잡는 것은 의심스럽습니다. 그래서 확인해보겠습니다.

# %%
fig, ax = plt.subplots(ncols=2, figsize=(10,4), dpi=100)
sns.countplot(data=data, x="blueEliteMonsters", hue="Wins", ax=ax[0], palette=palette)
sns.countplot(data=data, x="redEliteMonsters",hue="Wins", ax=ax[1], palette=palette)
plt.suptitle("Elite Monsters' Impact On The Game", va='baseline')

ax[0].set_title("Blue Team")
ax[0].set_xlabel("Number of elite monster blue team got")

ax[1].set_title("Red Team")
ax[1].set_xlabel("Number of elite monster red team got")

plt.tight_layout()

# %%
data[["blueEliteMonsters", "blueDragons","blueHeralds"]].query("blueEliteMonsters == 2")
# Out:
#       blueEliteMonsters  blueDragons  blueHeralds
# 23                    2            1            1
# 31                    2            1            1
# 52                    2            1            1
# 58                    2            1            1
# 63                    2            1            1
# ...                 ...          ...          ...
# 9803                  2            1            1
# 9804                  2            1            1
# 9850                  2            1            1
# 9862                  2            1            1
# 9871                  2            1            1
#
# [710 rows x 3 columns]

# %% [markdown]
# blueEliteMonsters이 게임 안에 버프몹 블루, 레드인 줄 알았지만,<br> 확인해본 결과 EliteMonsters는 Dragons과 Heralds를 처치한 수인 것으로 확인되었습니다.

# %%
bEM = data['blueEliteMonsters']
rEM = data['redEliteMonsters']
print(f"전체 게임 {len(data)}판 중에, 블루팀이 herald과 dragon을 잡은 게임은 {len(data[bEM == 2])} 게임입니다. 블루팀이 EliteMonsters를 두 마리를 잡았을 때 승률은 %{round(len(data[(bEM == 2) & (data['blueWins'] == 1)]) / len(data[bEM == 2]) * 100,2)} 입니다")
print(f"전체 게임 {len(data)}판 중에, 레드팀이 herald과 dragon을 잡은 게임은 {len(data[rEM == 2])} 게임입니다. 레드팀이 EliteMonsters를 두 마리를 잡았을 때 승률은 %{round(len(data[(rEM == 2) & (data['blueWins'] == 0)]) / len(data[rEM == 2]) * 100,2)} 입니다")
# Out:
# 전체 게임 9879판 중에, 블루팀이 herald과 dragon을 잡은 게임은 710 게임입니다. 블루팀이 EliteMonsters를 두 마리를 잡았을 때 승률은 %73.52 입니다
# 전체 게임 9879판 중에, 레드팀이 herald과 dragon을 잡은 게임은 730 게임입니다. 레드팀이 EliteMonsters를 두 마리를 잡았을 때 승률은 %71.37 입니다

# %% [markdown]
# <br>

# %%
print(f"전체 게임 {len(data)}판 중에, 블루팀이 herald과 dragon 중 하나만 잡은 게임은 {len(data[bEM == 1])} 게임입니다. 블루팀이 EliteMonsters 중 하나라도 잡았을 때 승률은 %{round(len(data[(bEM == 1) & (data['blueWins'] == 1)]) / len(data[bEM == 1]) * 100,2)} 입니다")
print(f"전체 게임 {len(data)}판 중에, 레드팀이 herald과 dragon 중 하나만 잡은 게임은 {len(data[rEM == 1])} 게임입니다. 레드팀이 EliteMonsters 중 하나라도 잡았을 때 승률은 %{round(len(data[(rEM == 1) & (data['blueWins'] == 0)]) / len(data[rEM == 1]) * 100,2)} 입니다")
# Out:
# 전체 게임 9879판 중에, 블루팀이 herald과 dragon 중 하나만 잡은 게임은 4013 게임입니다. 블루팀이 EliteMonsters 중 하나라도 잡았을 때 승률은 %58.63 입니다
# 전체 게임 9879판 중에, 레드팀이 herald과 dragon 중 하나만 잡은 게임은 4202 게임입니다. 레드팀이 EliteMonsters 중 하나라도 잡았을 때 승률은 %59.02 입니다

# %% [markdown]
# <br>

# %%
print(f"전체 게임 {len(data)}판 중에, 블루팀이 herald과 dragon 중 한 마리 이상 잡은 게임은 {len(data[bEM >= 1])} 게임입니다. 블루팀이 EliteMonsters를 한 마리 이상 잡았을 때 승률은 %{round(len(data[(bEM >= 1) & (data['blueWins'] == 1)]) / len(data[bEM >= 1]) * 100,2)} 입니다")
print(f"전체 게임 {len(data)}판 중에, 레드팀이 herald과 dragon 중 한 마리 이상 잡은 게임은 {len(data[rEM >= 1])} 게임입니다. 레드팀이 EliteMonsters를 한 마리 이상 잡았을 때 승률은 %{round(len(data[(rEM >= 1) & (data['blueWins'] == 0)]) / len(data[rEM >= 1]) * 100,2)} 입니다")
# Out:
# 전체 게임 9879판 중에, 블루팀이 herald과 dragon 중 한 마리 이상 잡은 게임은 4723 게임입니다. 블루팀이 EliteMonsters를 한 마리 이상 잡았을 때 승률은 %60.87 입니다
# 전체 게임 9879판 중에, 레드팀이 herald과 dragon 중 한 마리 이상 잡은 게임은 4932 게임입니다. 레드팀이 EliteMonsters를 한 마리 이상 잡았을 때 승률은 %60.85 입니다

# %% [markdown]
# <br>

# %%
print(f"전체 게임 {len(data)}판 중에, 블루팀이 herald과 dragon을 하나도 잡지 않은 게임은 {len(data[bEM == 0])} 게임입니다. 블루팀이 EliteMonsters를 한 마리도 잡지 않았을 때 승률은 %{round(len(data[(bEM == 0) & (data['blueWins'] == 1)]) / len(data[bEM == 0]) * 100,2)} 입니다")
print(f"전체 게임 {len(data)}판 중에, 레드팀이 herald과 dragon을 하나도 잡지 않은 게임은 {len(data[rEM == 0])} 게임입니다. 레드팀이 EliteMonsters를 한 마리도 잡지 않았을 때 승률은 %{round(len(data[(rEM == 0) & (data['blueWins'] == 0)]) / len(data[rEM == 0]) * 100,2)} 입니다")
# Out:
# 전체 게임 9879판 중에, 블루팀이 herald과 dragon을 하나도 잡지 않은 게임은 5156 게임입니다. 블루팀이 EliteMonsters를 한 마리도 잡지 않았을 때 승률은 %39.86 입니다
# 전체 게임 9879판 중에, 레드팀이 herald과 dragon을 하나도 잡지 않은 게임은 4947 게임입니다. 레드팀이 EliteMonsters를 한 마리도 잡지 않았을 때 승률은 %39.38 입니다

# %% [markdown]
# <br>

# %% [markdown]
# 용(dragon)과 협곡의 전령(herald)은 게임의 승리에 많은 영향을 줍니다.<br>다음은 dragon과 herald 중 어떤 오브젝트가 게임 승리에 더 영향을 주는지 확인해보겠습니다.

# %% [markdown]
# <br>

# %% [markdown]
# ## dragon과 herald

# %% [markdown]
# #### 1) dragon

# %%
fig, ax = plt.subplots(ncols=2, figsize=(12,4), dpi=100)
b = sns.countplot(data=data, x="blueDragons", hue="Wins", ax=ax[0], palette=palette)
r = sns.countplot(data=data, x="redDragons",hue="Wins", ax=ax[1], palette=palette)
plt.suptitle("Dragon's Impact On The Game", va='baseline')

b.set(xlabel=None)
r.set(xlabel=None)
b.set_title("BlueDragons")
r.set_title("RedDragons")

plt.tight_layout()

# %%
print(f"전체 게임 {len(data)}판 중에, 블루팀이 dragon을 잡은 게임은 {data.blueDragons.value_counts()[1]} 게임입니다. 블루팀이 dragon 잡았을 때 승률은 %{round(len(data[(data['blueDragons'] == 1) & (data['blueWins'] == 1)]) / data.blueDragons.value_counts()[1] * 100,2)} 입니다")
print(f"전체 게임 {len(data)}판 중에, 레드팀이 dragon을 잡은 게임은 {data.redDragons.value_counts()[1]} 게임입니다. 레드팀이 dragon 잡았을 때 승률은 %{round(len(data[(data['redDragons'] == 1) & (data['blueWins'] == 0)]) / data.redDragons.value_counts()[1] * 100,2)} 입니다")
# Out:
# 전체 게임 9879판 중에, 블루팀이 dragon을 잡은 게임은 3576 게임입니다. 블루팀이 dragon 잡았을 때 승률은 %64.09 입니다
# 전체 게임 9879판 중에, 레드팀이 dragon을 잡은 게임은 4081 게임입니다. 레드팀이 dragon 잡았을 때 승률은 %62.58 입니다

# %% [markdown]
# #### 2) herald

# %%
data["BlueHeralds"] = data.blueHeralds.map({0:"Red", 1:"Blue"})
data["RedHeralds"] = data.redHeralds.map({0:"Red", 1:"Blue"})

fig, ax = plt.subplots(ncols=2, figsize=(12,4), dpi=100)
sns.countplot(data=data, x="BlueHeralds", hue="Wins", ax=ax[0], palette=palette)
sns.countplot(data=data, x="RedHeralds",hue="Wins", ax=ax[1], palette=palette)
plt.suptitle("Heralds's Impact On The Game", va='baseline')

ax[0].set_title("Blue Team")
ax[1].set_title("Red Team")

plt.tight_layout()

# %%
print(f"전체 게임 {len(data)}판 중에, 블루팀이 Herald를 잡은 게임은 {data.blueHeralds.value_counts()[1]} 게임입니다. 블루팀이 Herald 잡았을 때 승률은 %{round(len(data[(data['blueHeralds'] == 1) & (data['blueWins'] == 1)]) / data.blueHeralds.value_counts()[1] * 100,2)} 입니다")
print(f"전체 게임 {len(data)}판 중에, 레드팀이 Herald를 잡은 게임은 {data.redHeralds.value_counts()[1]} 게임입니다. 레드팀이 Herald 잡았을 때 승률은 %{round(len(data[(data['redHeralds'] == 1) & (data['blueWins'] == 0)]) / data.redHeralds.value_counts()[1] * 100,2)} 입니다")
# Out:
# 전체 게임 9879판 중에, 블루팀이 Herald를 잡은 게임은 1857 게임입니다. 블루팀이 Herald 잡았을 때 승률은 %59.5 입니다
# 전체 게임 9879판 중에, 레드팀이 Herald를 잡은 게임은 1581 게임입니다. 레드팀이 Herald 잡았을 때 승률은 %61.23 입니다

# %% [markdown]
# ### dragon과 herald 결론
# <img src="https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2F2vrsb%2FbtrvCmTjTPF%2FI7TJ77WTy9EuwciWclHKe0%2Fimg.png" align="right" hspace=50 width="400" height="300">
# 분석 결과 레드팀이 dragon을 잡은 게임은 블루팀보다 505게임 더 많았고 블루팀이 Herald를 잡은 게임은 레드팀보다 276판 많았습니다. 게임 지도를 확인해본 결과 위쪽 레드 진영이 용에 접근하기 쉬운 지형을 가지고 있기 때문에 게임 시작 후 10분 안에 용을 블루팀보다 더 많이 잡을 수 있었던 것 같습니다. 반대로 블루팀도 Herald에 접근하기 쉬운 지형이라 레드팀보다 더 많이 잡을 수 있었습니다.
# <BR CLEAR=”left” />

# %% [markdown]
# <br>

# %% [markdown]
# ## TotalMinionsKilled (총 CS)
# <img src="https://i.postimg.cc/pLm1f5Ps/Cs6-TGmc-UIAAc7-VQ-0.jpg" align="right"  hspace=50 width="400" height="300">
#
# 미니언은 넥서스가 보내는 주력을 구성하는 유닛이다. 그들은 주기적으로 그들의 넥서스에서 생성되어 적 넥서스를 향해 이동하며, 그들이 마주치는 적 유닛이나 구조물과 자동으로 교전한다.
# <BR CLEAR=”left” />
#
# <a href="https://leagueoflegends.fandom.com/wiki/League_of_Legends_Wiki">League of Legends Wiki</a>

# %% [markdown]
# <br>

# %%
fig, ax = plt.subplots(ncols=2, figsize=(8,4), dpi=100)

b = sns.histplot(data=data, x="blueTotalMinionsKilled", bins=25, ax=ax[0], color=palette[1])
r = sns.histplot(data=data, x="redTotalMinionsKilled", bins=25, ax=ax[1], color=palette[0])

plt.suptitle("Total Minions Killed", va='baseline')

b.set(xlabel=None)
r.set(xlabel=None)
b.set_title("Blue Team")
r.set_title("Red Team")

plt.tight_layout()

# %%
print(f'블루팀이 이길 때, 블루팀이 평균적으로 처치한 미니언 수: {round(data[data["blueWins"]==1]["blueTotalMinionsKilled"].mean(),2)}마리')
print(f'레드팀이 이길 때, 레드팀이 평균적으로 처치한 미니언 수: {round(data[data["blueWins"]==0]["redTotalMinionsKilled"].mean(),2)}마리')
print('-'*66)
print(f'블루팀이 질 때, 블루팀이 평균적으로 처치한 미니언 수: {round(data[data["blueWins"]==0]["blueTotalMinionsKilled"].mean(),2)}마리')
print(f'레드팀이 질 때, 레드팀이 평균적으로 처치한 미니언 수: {round(data[data["blueWins"]==1]["redTotalMinionsKilled"].mean(),2)}마리')
# Out:
# 블루팀이 이길 때, 블루팀이 평균적으로 처치한 미니언 수: 221.62마리
# 레드팀이 이길 때, 레드팀이 평균적으로 처치한 미니언 수: 221.99마리
# ------------------------------------------------------------------
# 블루팀이 질 때, 블루팀이 평균적으로 처치한 미니언 수: 211.79마리
# 레드팀이 질 때, 레드팀이 평균적으로 처치한 미니언 수: 212.69마리

# %% [markdown]
# <br>

# %% [markdown]
# ## blueTotalJungleMinionsKilled

# %%
fig, ax = plt.subplots(ncols=2, figsize=(8,4), dpi=100)

g = sns.histplot(data=data, x="blueTotalJungleMinionsKilled", bins=25, ax=ax[0], color=palette[1])
j = sns.histplot(data=data, x="redTotalJungleMinionsKilled", bins=25, ax=ax[1], color=palette[0])

plt.suptitle("Total JungleMinions Killed", va='baseline')

g.set(xlabel=None)
j.set(xlabel=None)
g.set_title("Blue Team")
j.set_title("Red Team")

plt.tight_layout()

# %%
print(f'블루팀이 이길 때, 블루팀이 평균적으로 처치한 정글몹 수: {round(data[data["blueWins"]==1]["blueTotalJungleMinionsKilled"].mean(),2)}마리')
print(f'레드팀이 이길 때, 레드팀이 평균적으로 처치한 정글몹 수: {round(data[data["blueWins"]==0]["redTotalJungleMinionsKilled"].mean(),2)}마리')
print('-'*66)
print(f'블루팀이 질 때, 블루팀이 평균적으로 처치한 정글몹 수: {round(data[data["blueWins"]==0]["blueTotalJungleMinionsKilled"].mean(),2)}마리')
print(f'레드팀이 질 때, 레드팀이 평균적으로 처치한 정글몹 수: {round(data[data["blueWins"]==1]["redTotalJungleMinionsKilled"].mean(),2)}마리')
# Out:
# 블루팀이 이길 때, 블루팀이 평균적으로 처치한 정글몹 수: 51.81마리
# 레드팀이 이길 때, 레드팀이 평균적으로 처치한 정글몹 수: 52.42마리
# ------------------------------------------------------------------
# 블루팀이 질 때, 블루팀이 평균적으로 처치한 정글몹 수: 49.21마리
# 레드팀이 질 때, 레드팀이 평균적으로 처치한 정글몹 수: 50.2마리

# %% [markdown]
# <br>

# %% [markdown]
# ### Wards
# <img src="https://mblogthumb-phinf.pstatic.net/20150329_126/rpdlathtjf_1427614324784BAxxQ_JPEG/%BF%CD%B5%E5%C1%BE%B7%F9.jpg?type=w2" align="right" hspace=80 width="300" height="150">
#
# League of Legend에서 와드의 종류는 와드 토템, 일반 와드, 핑크 와드가 있습니다.
# 와드는 상대팀의 위치 정보를 알 수 있습니다. 핑크 와드는 투명화 된 유닛을 발견할 수 있습니다.

# %%
fig, ax = plt.subplots(ncols=2, figsize=(8,4), dpi=100)

g = sns.histplot(data=data, x="blueWardsPlaced", bins=25, ax=ax[0], color=palette[1])
j = sns.histplot(data=data, x="redWardsPlaced", bins=25, ax=ax[1], color=palette[0])

plt.suptitle("Total WardsPlaced", va='baseline')

g.set(xlabel=None)
j.set(xlabel=None)

g.set_xlim(0, 100)
j.set_xlim(0, 100)

g.set_title("Blue Team")
j.set_title("Red Team")

plt.tight_layout()

# %%
print(f'블루팀이 설치한 최대 와드 개수: {data["blueWardsPlaced"].max()}개')
print(f'레드팀이 설치한 최대 와드 개수: {data["redWardsPlaced"].max()}개')
# Out:
# 블루팀이 설치한 최대 와드 개수: 250개
# 레드팀이 설치한 최대 와드 개수: 276개

# %%
fig, ax = plt.subplots(ncols=2, figsize=(8,4), dpi=100)

g = sns.histplot(data=data, x="blueWardsDestroyed", bins=25, ax=ax[0], color=palette[1])
j = sns.histplot(data=data, x="redWardsDestroyed", bins=25, ax=ax[1], color=palette[0])

plt.suptitle("Total WardsDestroyed", va='baseline')

g.set_xlim(0, 30)
j.set_xlim(0, 30)

g.set(xlabel=None)
j.set(xlabel=None)

g.set_title("Blue Team")
j.set_title("Red Team")

plt.tight_layout()

# %%
print(f'블루팀이 파괴한 최대 와드 개수: {data["blueWardsDestroyed"].max()}개')
print(f'레드팀이 파괴한 최대 와드 개수: {data["redWardsDestroyed"].max()}개')
# Out:
# 블루팀이 파괴한 최대 와드 개수: 27개
# 레드팀이 파괴한 최대 와드 개수: 24개

# %%
print(f'블루팀이 이길 때, 블루팀이 평균적으로 설치한 와드 개수: {round(data[data["blueWins"]==1]["blueWardsPlaced"].mean(),2)}개')
print(f'블루팀이 이길 때, 블루팀이 평균적으로 파괴한 와드 개수: {round(data[data["blueWins"]==1]["blueWardsDestroyed"].mean(),2)}개')
print('-'*66)

print(f'레드팀이 이길 때, 레드팀이 평균적으로 설치한 와드 개수: {round(data[data["blueWins"]==0]["redWardsPlaced"].mean(),2)}개')
print(f'레드팀이 이길 때, 레드팀이 평균적으로 파괴한 와드 개수: {round(data[data["blueWins"]==0]["redWardsDestroyed"].mean(),2)}개')
# Out:
# 블루팀이 이길 때, 블루팀이 평균적으로 설치한 와드 개수: 22.29개
# 블루팀이 이길 때, 블루팀이 평균적으로 파괴한 와드 개수: 2.92개
# ------------------------------------------------------------------
# 레드팀이 이길 때, 레드팀이 평균적으로 설치한 와드 개수: 22.8개
# 레드팀이 이길 때, 레드팀이 평균적으로 파괴한 와드 개수: 2.84개

# %% [markdown]
# <br>

# %% [markdown]
# ### TowersDestroyed
#
# <img src="https://post-phinf.pstatic.net/MjAxODExMjNfMTk5/MDAxNTQyOTA4MzY2NzEy.8Ws5lIN3qVgiK5JyTnHdLccwZckJXIzrcyknJdRoFFwg.TjVutIE-XHU78BJGfMxBrb38rjKeyFu37wnCPgZRfPcg.GIF/160%EA%B3%A8%EB%93%9C.gif?type=w1200" align="right" hspace=80 width="350" height="250">
#
# 타워라고도 불리는 포탑은 시야에 들어오는 적의 부대를 공격하는 요새입니다. 포탑은 리그 오브 레전드의 핵심 구성요소입니다. 포탑은 적들에게 피해를 입히고 팀에게 시야를 제공해서 전장을 더 잘 통제할 수 있게 해줍니다. 포탑은 한 번에 한 대씩 조준해 큰 피해를 줍니다. 팀은 적의 포탑을 파괴하여 적진까지 공격해야 합니다.
#
# <BR CLEAR=”left” />
#
#
# <a href="https://leagueoflegends.fandom.com/wiki/League_of_Legends_Wiki">League of Legends Wiki</a>

# %%
fig, ax = plt.subplots(ncols=2, figsize=(8,4), dpi=100)
b = sns.countplot(data=data, x="blueTowersDestroyed", palette=palette, ax=ax[0])
r = sns.countplot(data=data, x="redTowersDestroyed", palette=palette, ax=ax[1])

plt.suptitle("Total TowersDestroyed", va='baseline')

plt.tight_layout()

# %% [markdown]
# ### 승리와 가장 밀접한 연관성이 있는 Feature 확인하기

# %%
cor = data.corr()
cor['blueWins'].sort_values(ascending=False)
# Out:
# blueWins                        1.000000
# blueGoldDiff                    0.511119
# blueExperienceDiff              0.489558
# blueTotalGold                   0.417213
# blueGoldPerMin                  0.417213
# blueTotalExperience             0.396141
# blueAvgLevel                    0.357820
# blueKills                       0.337358
# redDeaths                       0.337358
# blueAssists                     0.276685
# blueCSPerMin                    0.224909
# blueTotalMinionsKilled          0.224909
# blueEliteMonsters               0.221944
# blueDragons                     0.213768
# blueFirstBlood                  0.201769
# blueTotalJungleMinionsKilled    0.131445
# blueTowersDestroyed             0.115566
# blueHeralds                     0.092385
# blueWardsDestroyed              0.044247
# gameId                          0.000985
# blueWardsPlaced                 0.000087
# redWardsPlaced                 -0.023671
# redWardsDestroyed              -0.055400
# ...

# %% [markdown]
# #### 돈과 경험치가 게임을 이기는데 가장 큰 영향을 주는 것을 확인했습니다.

# %% [markdown]
# ### 골드차이에 영향을 주는 것 확인하기

# %%
cor = data.corr()
cor['blueGoldDiff'].sort_values(ascending=False)
# Out:
# blueGoldDiff                    1.000000
# blueExperienceDiff              0.894729
# blueTotalGold                   0.816803
# blueGoldPerMin                  0.816803
# blueTotalExperience             0.717968
# blueKills                       0.654148
# redDeaths                       0.654148
# blueAvgLevel                    0.653538
# blueAssists                     0.549761
# blueWins                        0.511119
# blueTotalMinionsKilled          0.450497
# blueCSPerMin                    0.450497
# blueFirstBlood                  0.378511
# blueTowersDestroyed             0.294060
# blueEliteMonsters               0.281464
# blueDragons                     0.233875
# blueTotalJungleMinionsKilled    0.167510
# blueHeralds                     0.162943
# blueWardsDestroyed              0.078585
# blueWardsPlaced                 0.015800
# gameId                         -0.014670
# redWardsPlaced                 -0.019042
# redWardsDestroyed              -0.099725
# ...

# %% [markdown]
# ### 경험치 차이에 영향을 주는 것 확인하기

# %%
cor = data.corr()
cor['blueExperienceDiff'].sort_values(ascending=False)
# Out:
# blueExperienceDiff              1.000000
# blueGoldDiff                    0.894729
# blueTotalExperience             0.800815
# blueGoldPerMin                  0.729345
# blueTotalGold                   0.729345
# blueAvgLevel                    0.718822
# redDeaths                       0.583730
# blueKills                       0.583730
# blueWins                        0.489558
# blueCSPerMin                    0.447264
# blueTotalMinionsKilled          0.447264
# blueAssists                     0.437002
# blueTotalJungleMinionsKilled    0.265443
# blueEliteMonsters               0.263991
# blueFirstBlood                  0.240665
# blueTowersDestroyed             0.218320
# blueDragons                     0.211496
# blueHeralds                     0.162496
# blueWardsDestroyed              0.077946
# blueWardsPlaced                 0.027943
# gameId                         -0.012315
# redWardsPlaced                 -0.026556
# redWardsDestroyed              -0.085829
# ...

# %% [markdown]
# ### 승리에 가장 큰 영향을 주는 골드차이와 경험치 차이간의 상관관계 히트맵으로 확인하기

# %%
cor = data.corr()
cor1 = cor[["blueWins", "blueGoldDiff", "blueExperienceDiff"]]
plt.figure(figsize=(10, 10))
sns.heatmap(cor1, cmap='Blues', annot=True, fmt='.2f', vmin=0);

# %% [markdown]
# # 데이터 전처리

# %%
df_clean = oriData.copy()

# %% [markdown]
# ### 서로 대칭 되는 데이터 확인하기

# %%
sns.pairplot(data=data, x_vars=["blueFirstBlood","blueKills","blueDeaths","blueGoldDiff","blueExperienceDiff"],
             y_vars=["redFirstBlood","redKills","redDeaths","redGoldDiff","redExperienceDiff"], hue="blueWins", palette=palette);

# %%
sameCol = ['redFirstBlood','redKills','redDeaths','redGoldDiff','redExperienceDiff','gameId']

# %%
df_clean.drop(sameCol, axis=1, inplace=True)

# %%
print(df_clean.columns)
print('Columns의 개수: ',str(len(df_clean.columns))+'개')
# Out:
# Index(['blueWins', 'blueWardsPlaced', 'blueWardsDestroyed', 'blueFirstBlood',
#        'blueKills', 'blueDeaths', 'blueAssists', 'blueEliteMonsters',
#        'blueDragons', 'blueHeralds', 'blueTowersDestroyed', 'blueTotalGold',
#        'blueAvgLevel', 'blueTotalExperience', 'blueTotalMinionsKilled',
#        'blueTotalJungleMinionsKilled', 'blueGoldDiff', 'blueExperienceDiff',
#        'blueCSPerMin', 'blueGoldPerMin', 'redWardsPlaced', 'redWardsDestroyed',
#        'redAssists', 'redEliteMonsters', 'redDragons', 'redHeralds',
#        'redTowersDestroyed', 'redTotalGold', 'redAvgLevel',
#        'redTotalExperience', 'redTotalMinionsKilled',
#        'redTotalJungleMinionsKilled', 'redCSPerMin', 'redGoldPerMin'],
#       dtype='object')
# Columns의 개수:  34개

# %% [markdown]
# ### 승리와 연관성이 떨어지는 항목 지우기(상관 계수가 절대값을 씌웠을 때 0.2보다 작으면 삭제)

# %%
df_clean.drop(['blueTotalJungleMinionsKilled','blueTowersDestroyed','blueHeralds','blueWardsDestroyed','blueWardsPlaced','redWardsPlaced',
           'redWardsDestroyed','redHeralds','redTowersDestroyed','redTotalJungleMinionsKilled'], axis=1, inplace=True)

# %% [markdown]
# ### blueWin 데이터의 상관 관계 분석

# %%
cor = df_clean.corr()
plt.figure(figsize=(16, 12))
sns.heatmap(cor, cmap='Blues', annot=True, fmt='.2f', vmin=0);

# %%
cor['blueWins'].sort_values(ascending=False)
# Out:
# blueWins                  1.000000
# blueGoldDiff              0.511119
# blueExperienceDiff        0.489558
# blueTotalGold             0.417213
# blueGoldPerMin            0.417213
# blueTotalExperience       0.396141
# blueAvgLevel              0.357820
# blueKills                 0.337358
# blueAssists               0.276685
# blueCSPerMin              0.224909
# blueTotalMinionsKilled    0.224909
# blueEliteMonsters         0.221944
# blueDragons               0.213768
# blueFirstBlood            0.201769
# redDragons               -0.209516
# redCSPerMin              -0.212171
# redTotalMinionsKilled    -0.212171
# redEliteMonsters         -0.221551
# redAssists               -0.271047
# blueDeaths               -0.339297
# redAvgLevel              -0.352127
# redTotalExperience       -0.387588
# redGoldPerMin            -0.411396
# redTotalGold             -0.411396
# Name: blueWins, dtype: float64

# %% [markdown]
# ### 알아보기 쉽게 데이터 이름 변경하기

# %%
df_clean.rename(columns={'blueWins':'Win', 'blueFirstBlood':'FirstBlood','blueKills':'Kills','blueDeaths':'Deaths',
                     'blueGoldDiff':'GoldDiff','blueExperienceDiff':'ExperienceDiff'}, inplace=True)

# %%
print(df_clean.columns)
# Out:
# Index(['Win', 'FirstBlood', 'Kills', 'Deaths', 'blueAssists',
#        'blueEliteMonsters', 'blueDragons', 'blueTotalGold', 'blueAvgLevel',
#        'blueTotalExperience', 'blueTotalMinionsKilled', 'GoldDiff',
#        'ExperienceDiff', 'blueCSPerMin', 'blueGoldPerMin', 'redAssists',
#        'redEliteMonsters', 'redDragons', 'redTotalGold', 'redAvgLevel',
#        'redTotalExperience', 'redTotalMinionsKilled', 'redCSPerMin',
#        'redGoldPerMin'],
#       dtype='object')

# %% [markdown]
# ### target 데이터에 해당하는 Win 제거 후 label 변수에 넣기

# %%
label = df_clean['Win']
del df_clean['Win']
print(df_clean.columns)
# Out:
# Index(['FirstBlood', 'Kills', 'Deaths', 'blueAssists', 'blueEliteMonsters',
#        'blueDragons', 'blueTotalGold', 'blueAvgLevel', 'blueTotalExperience',
#        'blueTotalMinionsKilled', 'GoldDiff', 'ExperienceDiff', 'blueCSPerMin',
#        'blueGoldPerMin', 'redAssists', 'redEliteMonsters', 'redDragons',
#        'redTotalGold', 'redAvgLevel', 'redTotalExperience',
#        'redTotalMinionsKilled', 'redCSPerMin', 'redGoldPerMin'],
#       dtype='object')

# %%
print(label)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 9874    1
# 9875    1
# 9876    0
# 9877    0
# 9878    1
# Name: Win, Length: 9879, dtype: int64

# %% [markdown]
# # 훈련 세트와 검증 세트, 테스트 세트 나누기

# %%
x_train, x_test, y_train, y_test = train_test_split(oriData, label, test_size=0.2, random_state=42)

# %%
print('train: {}, test: {}'.format(len(x_train), len(x_test)))
# Out:
# train: 7903, test: 1976

# %% [markdown]
# ## LogisticRegression 모델 사용하기

# %%
from sklearn.linear_model import LogisticRegression

logist_model = LogisticRegression(max_iter=500,      
                                 solver='liblinear')
logist_model.fit(x_train, y_train)
y_pred = logist_model.predict(x_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72       983
#            1       0.73      0.72      0.73       993
#
#     accuracy                           0.72      1976
#    macro avg       0.72      0.72      0.72      1976
# weighted avg       0.72      0.72      0.72      1976

# %%
plt.figure(figsize=(8,6))
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, cmap="Blues", annot=True, fmt='d')
plt.title("Confusion Metrix : Logistic Regression")
plt.ylabel("True label")
plt.xlabel("Predict label")
plt.show()

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(logist_model,x_train, y_train, cv=5)
# Out:
# array([0.72232764, 0.73308033, 0.7311828 , 0.73670886, 0.72405063])

# %%
from sklearn.metrics import accuracy_score
acc_LR = accuracy_score(y_test, y_pred)
print(acc_LR)
# Out:
# 0.7241902834008097

# %% [markdown]
# LogisticRegression 모델을 사용한 결과 f1-score가 0.72가 나왔고 precision 값과 recall 값의 차이가 없는 것을 확인했습니다. <br>정확도가 0.73인 것을 보아 이 데이터셋은 좋은 데이터셋이라는 것을 알 수 있었습니다.

# %% [markdown]
# ## 데이터 전처리 후 훈련을 진행했을 때

# %%
x_train, x_test, y_train, y_test = train_test_split(df_clean, label, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

logist_model = LogisticRegression(max_iter=500,      
                                 solver='liblinear')
logist_model.fit(x_train, y_train)
y_pred = logist_model.predict(x_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.72      0.73       983
#            1       0.73      0.74      0.73       993
#
#     accuracy                           0.73      1976
#    macro avg       0.73      0.73      0.73      1976
# weighted avg       0.73      0.73      0.73      1976

# %%
plt.figure(figsize=(8,6))
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, cmap="Blues", annot=True, fmt='d')
plt.title("Confusion Metrix : Logistic Regression")
plt.ylabel("True label")
plt.xlabel("Predict label")
plt.show()

# %%
cross_val_score(logist_model,x_train, y_train, cv=5)
# Out:
# array([0.72865275, 0.74067046, 0.72991777, 0.73860759, 0.72468354])

# %%
acc_LR = accuracy_score(y_test, y_pred)
print(acc_LR)
# Out:
# 0.729251012145749

# %% [markdown]
# 중복 데이터와 관련성이 떨어지는 Feature를 제거 한 결과가 조금 더 좋은 결과를 얻은 것을 확인했습니다. 현재 제거한 데이터의 기준이 0.2로 낮기 때문에 정확도 상승이 적은 것 같습니다.

# %% [markdown]
# <br>

# %% [markdown]
# # 결론
#
# 1. 게임을 이기는데 가장 큰 영향을 주는 것은 돈과 경험치 입니다. 골드와 경험치는 승리와 비례하는 것을 볼 수 있습니다. 아래를 보면 골드와 경험치, 승리는 서로에게 긍정적인 영향을 주는 것을 직접 확인했습니다.
# <br>
#
# ![League of Leagend 승리 공식](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FCT81y%2FbtrvDgNavH4%2FBNqjxjJzNJC2NCVzh5xCNK%2Fimg.png)

# %% [markdown]
# 2. 현재 우리가 가지는 데이터로는 각 라인별 영향력과 밸런스를 파괴시키는 챔피언에 대해서 알 수 없었다.

# %% [markdown]
# 3. 레드팀이 블루팀보다 dragon을 많이 사냥한 것과 블루팀이 레드팀보다 Herald를 사냥한 게임이 많다는 것을 통해 우리는 리그 오브 레전드에서 지형이 가지는 이점을 파악할 수 있었다. 게임을 직접 봤을 때 오브젝트를 챙기는 것이 승률에 많은 영향을 준다고 생각했지만 10분 이전의 데이터를 통해서는 그 중요도가 나오지 않은 것 같다.

# %% [markdown]
# 4. 협곡의 전령의 효과에 있어 그 능력이 즉각적인 효과가 나타나는 용과 다르게 사용자가 직접 사용해야 한다는 점에 의해 우리가 가지고 있는 10분 이전의 데이터셋에서 전령의 영향력이 나오지않은 것 같다. 만약 20분까지의 데이터였다면 포탑 골드를 수급하는데 도움이 되는 전령의 영향력이 용보다 컸을 것이다.

# %% [markdown]
# 5. 와드 또한 게임에서 영향을 크게 끼치는 요소이지만 상관계수 분석에서는 낮은 관계도를 보였다. 이는 데이터상에서 단순히 와드를 박은 횟수만 있기때문이다. 와드는 박는 횟수가 중요한것이 아니라 박는 시점, 위치 가 중요 하기때문이다. <br>그리고 와드는 사람의 판단에 영향을 주기 때문에 데이터를 통해 그 영향력이 표현되지 않은 것 같다.

# %% [markdown]
# 6. 이 데이터셋은 약 2년전의 데이터라서 이 데이터셋을 통해 현재의 승률을 예측하기는 어렵다.
#
#
# ![League of Leagend 승리 패치](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FvBlCW%2FbtrvDP2VOdI%2Fs0VMjrpyFnMM0oJLsVrCy1%2Fimg.png)
#
# <a href="https://lol.ps/ko/notice/">League o Legends 패치노트</a>

# %% [markdown]
# 추후에 라이엇 개발자 홈페이지를 통해 데이터를 수집해서 분석을 해 볼 예정입니다.<br>
# <a href="https://shinminyong.tistory.com/11">League o Legends 개발자 API를 통한 데이터 수집</a>
